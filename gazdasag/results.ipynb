# %%
Alapterkep

# %%
3D terkep
# Out:
# C:\Program Files\Anaconda\lib\site-packages\IPython\core\formatters.py:239: FormatterWarning: Exception in text/html formatter: array([ 24.25,  26.5 ]) is not JSON serializable
#   FormatterWarning,

# %%
Iparagak eloszlasa faterkeppel (Szinkod marad folulrol)

from IPython.display import HTML
HTML('<iframe src=http://blog.csaladen.es/\
szekelyfold%20omnibus/treemap.html width=1050 height=550></iframe>')
# Out:
# <iframe src=http://blog.csaladen.es/szekelyfold%20omnibus/treemap.html width=1050 height=550></iframe>

# %%
Regiok eloszlasa faterkeppel (Szinkod marad folulrol)

from IPython.display import HTML
HTML('<iframe src=http://blog.csaladen.es/\
szekelyfold%20omnibus/treemap2.html width=1050 height=550></iframe>')
# Out:
# <iframe src=http://blog.csaladen.es/szekelyfold%20omnibus/treemap2.html width=1050 height=550></iframe>

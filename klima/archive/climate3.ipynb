# %%
import pandas as pd, numpy as np

# %%
ro=['5765358043206','9812808043220','9576658043223','1699958043227','7225068043228','265208043229']
hu=['8073718043234','2087988043232','6247548043235']

# %%
stations=[]
for i in ro+hu:
    stations.append(pd.read_csv(i+'stn+.txt',delimiter= '+',skiprows=2,header=None))
    print(i)
# Out:
# 5765358043206
# 9812808043220
# 9576658043223
# 1699958043227
# 7225068043228
# 265208043229
# 8073718043234
# 2087988043232
# 6247548043235

# %%
station=pd.concat(stations)

# %%
station=station.drop_duplicates()

# %%
station[2]=station[2].str.strip()
station[3]=station[3].str.strip()

# %%
dfs=[]
for i in ro+hu:
    df=pd.read_csv(i+'dat.txt',delimiter= '\s+')
    df=df.replace({'******':np.nan,'*****':np.nan,'****':np.nan,'***':np.nan,'**':np.nan,'*':np.nan})
    df['time']=pd.to_datetime(df['YR--MODAHRMN'],format='%Y%m%d%H%M')
    df=df[['time','USAF','SPD','TEMP','PCP06','SD','MW','AW','W']]
    df['TEMP']=(pd.to_numeric(df['TEMP'], errors='coerce')-32)*5/9
    df['SPD']=pd.to_numeric(df['SPD'], errors='coerce')*1.61
    df['PCP06']=pd.to_numeric(df['PCP06'], errors='coerce')*25.4
    df['SD']=pd.to_numeric(df['SD'], errors='coerce')*25.4
    dfs.append(df)
    print(i)
# Out:
# 5765358043206
# 9812808043220
# 9576658043223
# 1699958043227
# 7225068043228
# 265208043229
# C:\ProgramData\Anaconda3\envs\plotly\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning:
#
# Columns (4,11,12,21,22,23,25) have mixed types. Specify dtype option on import or set low_memory=False.
# 8073718043234
# 2087988043232
# C:\ProgramData\Anaconda3\envs\plotly\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning:
#
# Columns (4,11,12,20,21,22,23,24,25) have mixed types. Specify dtype option on import or set low_memory=False.
# 6247548043235

# %%
dfs=pd.concat(dfs)

# %%
dfs=dfs.drop_duplicates()

# %%
dfs.to_csv('data/all.csv')

# %%
# dfs=pd.read_csv('data/all.csv')

# %%
dfs['time']=pd.to_datetime(dfs['time'])
dfs['year']=dfs['time'].dt.year
dfs['month']=dfs['time'].dt.month
dfs['day']=dfs['time'].dt.day
dfs['hour']=dfs['time'].dt.hour

# %%
df=dfs.groupby(['USAF','year','month','day','hour'])[['TEMP','SPD','SD','PCP06']]

# %%
df_avg=df.mean()

# %%
df_avg.columns=['temp_avg','spd_avg','snow_avg','rain_avg']

# %%
df_avg=np.round(df_avg,1)

# %%
#keep only months with at least 6 days to avoid anomalies (20%)
filt=df_avg.reset_index().groupby(['USAF','year','month'])[['day']].nunique()
filt2=filt[filt>5].dropna()

# %%
#keep only years with at least 3 months to avoid anomalies (20%)
filt3=filt2.reset_index().groupby(['USAF','year'])[['month']].nunique()
filt4=filt3[filt3>3].dropna()

# %%
df_avg2=df_avg.reset_index().set_index(['USAF','year'])

# %%
dfz={}

# %%
for i in filt4.index.unique(0):
    d=df_avg2.loc[i].loc[filt4.loc[i].index.unique()]
    dfz[i]=d
    d.to_csv('data/'+str(i)+'.csv')
    print(i)
# Out:
# 119000
# 127560
# 127660
# 127720
# 127860
# 128050
# 128120
# 154090.csv
# 154100.csv
# 154120.csv
# 154160.csv
# 154190.csv
# 154200.csv
# 154210.csv
# 154215.csv
# 154220.csv
# 154230.csv
# 154240.csv
# 154250.csv
# 154280.csv
# 154290.csv
# 154340.csv
# 154430.csv
# 154440.csv
# 154450.csv
# 154470.csv
# 154500.csv
# 154510.csv
# 154550.csv
# 154600.csv
# 154620.csv
# 154650.csv
# 154690.csv
# 154700.csv
# 154750.csv
# 154760.csv
# 154770.csv
# 154790.csv
# 154800.csv
# 154810.csv
# 154820.csv
# 154890.csv
# 154900.csv
# 154910.csv
# 154930.csv
# 154931.csv
# 154940.csv
# 154980.csv
# 154990.csv

# %%
stationc=station.set_index(0)[2]

# %%
stationx={}
for z in dfz:
    stationx[stationc.loc[int(z)]]={'id':z,'yrs':len(dfz[z]['year'].unique())}

# %%
dq=pd.DataFrame(stationx).T.reset_index().set_index('yrs').sort_index(ascending=False)

# %%
dq.head(5)
# Out:
#                      index      id
# yrs
# 72            AUREL VLAICU  154200
# 68                  GALATI  153100
# 67             CLUJ NAPOCA  151200
# 67   DROBETA TURNU SEVERIN  154100
# 66               CONSTANTA  154800

# %%
dds=[]
indicator='temp_avg'
for a in dq.head(500)['id'].values:
    dw=dfz[a]
    tmean=dw.groupby(['month','hour']).mean()[[indicator]]
    tmean.columns=['temp_mean']
    dw=dw.loc[1980:]
    dw=dw.loc[:2010]
    tmean80=dw.groupby(['month','hour']).mean()[[indicator]]
    tmean80.columns=['temp_mean80']
    dc=dfz[a].groupby(['year','month','hour']).mean()[[indicator]].join(tmean).join(tmean80)
    dc['temp_delta']=dc[indicator]-dc['temp_mean']
    dc['temp_delta80']=dc[indicator]-dc['temp_mean80']
    dd=dc.groupby(['year']).mean()
    dd=np.round(dd,1)
    dd['varos']=stationc[int(a)]
    dd['value']=1
    dds.append(dd)
ddb=pd.concat(dds)
ddb.to_csv('stripes/geo.csv')

# %%
dgeo=ddb.reset_index().set_index('varos').join(station.set_index(2))
dgeo[dgeo[3]=='HUNGARY'].to_csv('stripes/geotest.csv')

# %%
dgeo.loc['BUDAPEST MET CENTER']
# Out:
#                      year  temp_avg  temp_mean  temp_mean80  temp_delta  \
# BUDAPEST MET CENTER  1931      10.7       11.4          8.8        -0.7
# BUDAPEST MET CENTER  1932      11.0       11.4          8.8        -0.4
# BUDAPEST MET CENTER  1933      10.5       11.4          8.8        -0.9
# BUDAPEST MET CENTER  1934      12.7       11.4          8.8         1.2
# BUDAPEST MET CENTER  1935      11.5       11.4          8.8         0.1
# BUDAPEST MET CENTER  1936      11.9       11.4          8.8         0.5
# BUDAPEST MET CENTER  1937      11.9       11.4          8.8         0.5
# BUDAPEST MET CENTER  1938      11.9       11.4          8.8         0.5
# BUDAPEST MET CENTER  1939      14.0       13.1          8.8         0.9
# BUDAPEST MET CENTER  1952      11.0       10.8          8.8         0.3
# BUDAPEST MET CENTER  1953      11.2       10.8          8.8         0.4
# BUDAPEST MET CENTER  1954      10.0       10.8          8.8        -0.8
# BUDAPEST MET CENTER  1955      10.3       10.8          8.8        -0.5
# BUDAPEST MET CENTER  1956       9.5       10.8          8.8        -1.3
# BUDAPEST MET CENTER  1959      11.0       11.5          NaN        -0.5
# BUDAPEST MET CENTER  1960      11.2       11.1          8.8         0.2
# BUDAPEST MET CENTER  1992      16.6       15.5          8.8         1.1
# BUDAPEST MET CENTER  1993      11.9       11.4         11.8         0.3
#
#                      temp_delta80  value       0      1        3       4  \
# BUDAPEST MET CENTER           1.4      1  128400  99999  HUNGARY  47.517
# BUDAPEST MET CENTER           3.1      1  128400  99999  HUNGARY  47.517
# BUDAPEST MET CENTER           1.1      1  128400  99999  HUNGARY  47.517
# BUDAPEST MET CENTER           5.6      1  128400  99999  HUNGARY  47.517
# BUDAPEST MET CENTER           3.0      1  128400  99999  HUNGARY  47.517
# BUDAPEST MET CENTER           3.4      1  128400  99999  HUNGARY  47.517
# BUDAPEST MET CENTER           2.3      1  128400  99999  HUNGARY  47.517
# BUDAPEST MET CENTER           0.5      1  128400  99999  HUNGARY  47.517
# BUDAPEST MET CENTER           6.6      1  128400  99999  HUNGARY  47.517
# BUDAPEST MET CENTER           6.8      1  128400  99999  HUNGARY  47.517
# BUDAPEST MET CENTER           4.1      1  128400  99999  HUNGARY  47.517
# BUDAPEST MET CENTER           0.6      1  128400  99999  HUNGARY  47.517
# BUDAPEST MET CENTER           0.3      1  128400  99999  HUNGARY  47.517
# BUDAPEST MET CENTER           2.6      1  128400  99999  HUNGARY  47.517
# BUDAPEST MET CENTER           NaN      1  128400  99999  HUNGARY  47.517
# BUDAPEST MET CENTER           2.8      1  128400  99999  HUNGARY  47.517
# BUDAPEST MET CENTER           4.6      1  128400  99999  HUNGARY  47.517
# BUDAPEST MET CENTER          -1.8      1  128400  99999  HUNGARY  47.517
#
#                           5      6
# BUDAPEST MET CENTER  19.033  129.0
# BUDAPEST MET CENTER  19.033  129.0
# BUDAPEST MET CENTER  19.033  129.0
# BUDAPEST MET CENTER  19.033  129.0
# BUDAPEST MET CENTER  19.033  129.0
# BUDAPEST MET CENTER  19.033  129.0
# BUDAPEST MET CENTER  19.033  129.0
# BUDAPEST MET CENTER  19.033  129.0
# BUDAPEST MET CENTER  19.033  129.0
# BUDAPEST MET CENTER  19.033  129.0
# BUDAPEST MET CENTER  19.033  129.0
# BUDAPEST MET CENTER  19.033  129.0
# BUDAPEST MET CENTER  19.033  129.0
# BUDAPEST MET CENTER  19.033  129.0
# BUDAPEST MET CENTER  19.033  129.0
# BUDAPEST MET CENTER  19.033  129.0
# BUDAPEST MET CENTER  19.033  129.0
# BUDAPEST MET CENTER  19.033  129.0

# %%
dw.groupby(['month','hour']).mean().loc[[(i,j) for i in [1,4,7,10] for j in [0,6,12,18]]][indicator].count()
# Out:
# 16

# %%
# Out:
#             year        day   temp_avg    spd_avg  snow_avg  rain_avg
# month hour
# 1     0     1952  15.620690  -0.053571  12.031034       NaN       NaN
#       0     1953  16.000000  -2.687097  14.893548       NaN       NaN
#       0     1954  16.931034  -9.058621  13.648276       NaN       NaN
#       0     1955  16.037037  -1.307692  10.781481       NaN       NaN
#       0     1956  16.551724  -1.462963   7.927586       NaN       NaN
# ...          ...        ...        ...        ...       ...       ...
# 10    18    2015  16.000000  10.729032   7.364516       NaN       NaN
#       18    2016  16.000000   9.693548   8.003226  0.819355       NaN
#       18    2017  16.000000  11.416129   6.041935  1.638710       NaN
#       18    2018  16.000000  12.974194   5.135484  0.000000       NaN
#       18    2019   1.000000  18.300000   8.900000  0.000000       NaN
#
# [1090 rows x 6 columns]

# %%
dds=[]
indicator='temp_avg'
clean_months=[1,4,7,10]
clean_hours=[0,6,12,18]
clean_slice=[(i,j) for i in clean_months for j in clean_hours]
for a in dq['id'].values:
    dw=dfz[a].groupby(['month','hour']).mean().loc[clean_slice]
    if dw[indicator].count()==len(clean_hours)*len(clean_months):
        tmean=dw.groupby(['month','hour']).mean()[[indicator]]
        tmean.columns=['temp_mean']
        dc=dfz[a].set_index(['month','hour']).loc[clean_slice].reset_index()
        dx=dc.groupby(['year']).nunique()
        full_data_years=dx[((dx['month']==len(clean_months))&(dx['hour']==len(clean_hours)))].index
        dc=dc.groupby(['year','month','hour']).mean()[[indicator]].loc[full_data_years].join(tmean)
        dc['temp_delta']=dc[indicator]-dc['temp_mean']
        dd=dc.groupby(['year']).mean()
        dd=np.round(dd,1)
        dd['varos']=stationc[int(a)]
        dd['value']=1
        dds.append(dd)
ddb=pd.concat(dds)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike

# %%
dgeo=ddb.reset_index().set_index('varos').join(station.set_index(2))
dgeo[dgeo[3]=='HUNGARY'].to_csv('stripes/hu.csv')
# dgeo[dgeo[3]=='ROMANIA'].to_csv('stripes/geotest.csv')
# dgeo.to_csv('stripes/geotest.csv')

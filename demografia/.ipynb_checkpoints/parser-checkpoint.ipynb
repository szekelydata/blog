# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from jupyterthemes import jtplot
# oceans16 | grade3 | chesterish | onedork | monokai | solarizedl
jtplot.style('solarized-light')

# %%
df=pd.concat([pd.read_csv('db/exportPivot_POP107D ('+str(i)+').csv') for i in range(0,26)],axis=0)

# %%
df.head()
# Out:
#   Varste si grupe de varsta       Sexe     Judete  \
# 0                  0- 4 ani   Masculin   Harghita
# 1                  0- 4 ani   Masculin   Harghita
# 2                  0- 4 ani   Masculin   Harghita
# 3                  0- 4 ani   Masculin   Harghita
# 4                  0- 4 ani   Masculin   Harghita
#
#                         Localitati          Ani  UM: Numar persoane   Valoare
# 0   83320 MUNICIPIUL MIERCUREA CIUC   Anul 2009      Numar persoane      1150
# 1   83320 MUNICIPIUL MIERCUREA CIUC   Anul 2010      Numar persoane      1165
# 2   83320 MUNICIPIUL MIERCUREA CIUC   Anul 2011      Numar persoane      1119
# 3   83320 MUNICIPIUL MIERCUREA CIUC   Anul 2012      Numar persoane      1103
# 4   83320 MUNICIPIUL MIERCUREA CIUC   Anul 2013      Numar persoane      1075

# %%
df.columns
# Out:
# Index([u'Varste si grupe de varsta', u' Sexe', u' Judete', u' Localitati ',
#        u' Ani', u' UM: Numar persoane', u' Valoare'],
#       dtype='object')

# %%
fig,ax=plt.subplots(1,1,figsize=(14,3))
sns.stripplot(x=u' Judete', y=' Valoare', hue=' Sexe', split=True,\
               data=df[df[' Ani']==' Anul 2017'], ax=ax, jitter=True)
plt.show()

# %%
dg=df.set_index(' Localitati ')

# %%
for i in dg.index.unique():
    dg.loc[i].to_csv('data/'+i+'.csv')

# %%
import json
file('locs.json','w').write(json.dumps(list(dg.index.unique())))

# %%
import pandas as pd, numpy as np
import itertools, requests, json

# %%
df=pd.read_excel('data/szekelyhon_data.xlsx')

# %%
df
# Out:
#     index       date              hudate  \
# 0       0 2018-10-02   2018. október 02.
# 1       1 2018-10-03   2018. október 03.
# 2       2 2018-10-05   2018. október 05.
# 3       3 2018-10-08   2018. október 08.
# 4       4 2018-10-10   2018. október 10.
# 5       5 2018-10-17   2018. október 17.
# 6       6 2018-10-18   2018. október 18.
# 7       7 2018-10-18   2018. október 18.
# 8       8 2018-10-18   2018. október 18.
# 9       9 2018-10-20   2018. október 20.
# 10     10 2018-10-31   2018. október 31.
# 11     11 2018-11-03  2018. november 03.
# 12     12 2018-11-03  2018. november 03.
# 13     13 2018-11-16  2018. november 16.
# 14     14 2018-11-21  2018. november 21.
# 15     15 2018-12-02  2018. december 02.
# 16     16 2018-12-03  2018. december 03.
# 17     17 2018-12-04  2018. december 04.
# 18     18 2018-12-10  2018. december 10.
# 19     19 2018-12-11  2018. december 11.
# 20     20 2019-01-06    2019. január 06.
# 21     21 2019-01-09    2019. január 09.
# ...

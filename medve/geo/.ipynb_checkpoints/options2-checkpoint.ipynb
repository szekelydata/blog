# %%
import pandas as pd, json

# %%
hun=json.loads(open('hun.json','r').read())

# %%
huncoords=json.loads(open('huncoords.json','r').read())

# %%
coords=json.loads(open('coords.json','r').read())

# %%
mind=json.loads(open('dict.json','r').read())

# %%
mindhu={}
megyeconv={'1':'MURES','8':'HARGHITA','6':'COVASNA'}
for i in mind:
    m=i[0]
    varos=i[i.find(' ')+1:]
    if varos not in mindhu:
        mindhu[varos]=[mind[i][2],mind[i][3],megyeconv[m]]
    else:
        print(varos,i)
        pass
# Out:
# SUSENI 119723 SUSENI

# %%
megye=['HARGHITA','COVASNA','MURES']

# %%
mindhu
# Out:
# {'BALA': [[46.7121253, 24.4979748], 'Bala', 'MURES'],
#  'ZAGAR': [[46.3506, 24.6181], 'Zágor', 'MURES'],
#  'ORAS UNGHENI': [[46.485833, 24.460833], 'Nyárádtõ', 'MURES'],
#  'VALEA LARGA': [[46.62, 24.07], 'Mezõceked', 'MURES'],
#  'ULIES': [[46.2112783, 25.2420621], 'Kányád', 'HARGHITA'],
#  'MIHESU DE CIMPIE': [[46.68000000000001, 24.15], 'Mezõméhes', 'MURES'],
#  'HODOSA': [[46.6369073, 24.823399], 'Székelyhodos', 'MURES'],
#  'EREMITU': [[46.66098040000001, 24.9273587], 'Nyárádremete', 'MURES'],
#  'GLODENI': [[46.6549681, 24.6080416], 'Marossárpatak', 'MURES'],
#  'BRADESTI': [[46.34116119999999, 25.3407935], 'Fenyéd', 'HARGHITA'],
#  'MUNICIPIUL REGHIN': [[46.77583300000001, 24.708333], 'Szászrégen', 'MURES'],
#  'ORAS VLAHITA': [[46.35, 25.53], 'Szentegyháza', 'HARGHITA'],
#  'SINCAI': [[46.655366, 24.392263], 'Mezõsámsod', 'MURES'],
#  'PRAID': [[46.55, 25.133333], 'Parajd', 'HARGHITA'],
#  'IDECIU DE JOS': [[46.8154513, 24.7568272], 'Alsóidecs', 'MURES'],
#  'BICHIS': [[46.3753746, 24.0911289], 'Magyarbükkös', 'MURES'],
#  'MOACSA': [[45.866667, 25.966667], 'Maksa', 'COVASNA'],
#  'TUSNAD': [[46.2068655, 25.9119481], 'Tusnád', 'HARGHITA'],
#  'CEUASU DE CIMPIE': [[46.64040749999999, 24.5145836], 'Mezõcsávás', 'MURES'],
#  'PLAIESII DE JOS': [[46.22490819999999, 26.1004859],
#   'Kászonaltíz',
#   'HARGHITA'],
#  'ORAS SOVATA': [[46.596111, 25.074444], 'Szováta', 'MURES'],
#  'GHEORGHE DOJA': [[46.4635769, 24.5078157], 'Lukafalva', 'MURES'],
#  'FRUMOASA': [[46.45484, 25.8515132], 'Csíkszépvíz', 'HARGHITA'],
#  'OZUN': [[45.8, 25.85], 'Uzon', 'COVASNA'],
#  'JOSENI': [[46.7, 25.5], 'Gyergyóalfalu', 'HARGHITA'],
#  'POGACEAUA': [[46.6769566, 24.3080262], 'Mezõpagocsa', 'MURES'],
#  'MUNICIPIUL SFINTU GHEORGHE': [[45.863611, 25.7875],
#   'Sepsiszentgyörgy',
#   'COVASNA'],
#  'SINTANA DE MURES': [[46.57000000000001, 24.55], 'Marosszentanna', 'MURES'],
#  'LUETA': [[46.2747298, 25.4914355], 'Lövéte', 'HARGHITA'],
#  'CUCI': [[46.4634727, 24.1553106], 'Kutyfalva', 'MURES'],
#  'CHIHERU DE JOS': [[46.6861581, 24.8741279], 'Alsóköhér', 'MURES'],
#  'POIAN': [[46.0696927, 26.1598138], 'Kézdiszentkereszt', 'COVASNA'],
#  'CIUCSINGEORGIU': [[46.316667, 25.95], 'Csíkszentgyörgy', 'HARGHITA'],
#  'TAURENI': [[46.5798792, 24.082425], 'Mezõtóhát', 'MURES'],
#  'BRADUT': [[46.1289647, 25.6101146], 'Bardóc', 'COVASNA'],
#  'BAND': [[46.5762629, 24.3743048], 'Mezõbánd', 'MURES'],
#  'OCLAND': [[46.1628838, 25.4251311], 'Oklánd', 'HARGHITA'],
#  'FARAGAU': [[46.76348609999999, 24.5148013], 'Faragó', 'MURES'],
#  'MERESTI': [[46.2343918, 25.4569963], 'Homoródalmás', 'HARGHITA'],
#  'SACEL': [[46.3129807, 24.9298014], 'Székelyandrásfalva', 'HARGHITA'],
#  'SINGEORGIU DE MURES': [[46.5792435, 24.608682], 'Marosszentgyörgy', 'MURES'],
#  'BRETCU': [[46.04342459999999, 26.3028187], 'Bereck', 'COVASNA'],
#  'VILCELE': [[45.8537981, 25.6840786], 'Elõpatak', 'COVASNA'],
#  'BATANI': [[46.089444, 25.691389], 'Nagybacon', 'COVASNA'],
#  'SARMAS': [[46.8799773, 25.4549439], 'Salamás', 'HARGHITA'],
#  'HODAC': [[46.7769539, 24.9262556], 'Görgényhodák', 'MURES'],
#  'ORAS SARMASU': [[46.753611, 24.166667], 'Nagysármás', 'MURES'],
#  'BILBOR': [[47.0656143, 25.4864041], 'Bélbor', 'HARGHITA'],
#  'MUNICIPIUL MIERCUREA CIUC': [[46.358, 25.804], 'Csíkszereda', 'HARGHITA'],
#  'DIRJIU': [[46.2, 25.2], 'Székelyderzs', 'HARGHITA'],
#  'VATAVA': [[46.966667, 24.766667], 'Felsõrépás', 'MURES'],
#  'GORNESTI': [[46.6708485, 24.6507173], 'Gernyeszeg', 'MURES'],
#  'SICULENI': [[46.4374818, 25.7531516], 'Madéfalva', 'HARGHITA'],
#  'DEALU': [[46.3959239, 25.3039301], 'Oroszhegy', 'HARGHITA'],
#  'RASTOLITA': [[46.9733161, 24.9917231], 'Ratosnya', 'MURES'],
#  'ZETEA': [[46.383333, 25.366667], 'Zetelaka', 'HARGHITA'],
#  'ZAGON': [[45.766667, 26.116667], 'Zágon', 'COVASNA'],
#  'MUGENI': [[46.25703499999999, 25.2210098], 'Bögöz', 'HARGHITA'],
#  'RECI': [[45.8398226, 25.9229125], 'Réty', 'COVASNA'],
#  'BATOS': [[46.8865613, 24.6517966], 'Bátos', 'MURES'],
#  'NEAUA': [[46.47843290000001, 24.8301881], 'Havad', 'MURES'],
#  'HAGHIG': [[45.8391349, 25.5892157], 'Hídvég', 'COVASNA'],
#  'CHICHIS': [[45.7707805, 25.7997157], 'Kökös', 'COVASNA'],
#  'ORAS SANGEORGIU DE PADURE': [[46.43027800000001, 24.841667],
#   'Erdõszentgyörgy',
#   'MURES'],
#  'MICA': [[46.36722049999999, 24.4101129], 'Mikefalva', 'MURES'],
#  'CAPILNITA': [[46.3594353, 25.511701], 'Kápolnásfalu', 'HARGHITA'],
#  'VIRGHIS': [[45.9426347, 25.8918984], 'Vargyas', 'COVASNA'],
#  'ORAS IERNUT': [[46.453611, 24.233333], 'Radnót', 'MURES'],
#  'SAULIA': [[46.633333, 24.216667], 'Mezõsályi', 'MURES'],
#  'IBANESTI': [[46.7704043, 24.9322946], 'Libánfalva', 'MURES'],
#  'ACATARI': [[46.479789, 24.6353545], 'Ákosfalva', 'MURES'],
#  'GURGHIU': [[46.7687756, 24.8559776], 'Görgényszentimre', 'MURES'],
#  'LIVEZENI': [[46.55, 24.633333], 'Jedd', 'MURES'],
#  'TURIA': [[46.0512486, 26.0422425], 'Torja', 'COVASNA'],
#  'SUSENI': [[46.666667, 25.55], 'Gyergyóújfalu', 'HARGHITA'],
#  'ALUNIS': [[46.8941662, 24.8205851], 'Magyaró', 'MURES'],
#  'SINPAUL': [[46.45, 24.35], 'Kerelõszentpál', 'MURES'],
#  'LUNCA DE JOS': [[46.5711344, 25.9769607], 'Gyimesközéplok', 'HARGHITA'],
#  'GALAUTAS': [[46.912712, 25.4042124], 'Galócás', 'HARGHITA'],
#  'SINDOMINIC': [[46.583333, 25.783333], 'Csíkszentdomokos', 'HARGHITA'],
#  'SANGER': [[46.55, 24.13], 'Mezõszengyel', 'MURES'],
#  'GHINDARI': [[46.5054469, 24.9235061], 'Makfalva', 'MURES'],
#  'CERNAT': [[45.95, 26.033333], 'Csernáton', 'COVASNA'],
#  'TULGHES': [[46.9502975, 25.7568596], 'Gyergyótölgyes', 'HARGHITA'],
#  'SINZIENI': [[45.9426347, 25.8918984], 'Kézdiszentlélek', 'COVASNA'],
#  'OJDULA': [[45.98333299999999, 26.25], 'Ozsdola', 'COVASNA'],
#  'LUNCA BRADULUI': [[46.9589754, 25.1086962], 'Palotailva', 'MURES'],
#  'MARTINIS': [[46.23333299999999, 25.383333],
#   'Homoródszentmárton',
#   'HARGHITA'],
#  'BREAZA': [[46.7662233, 24.6378932], 'Beresztelke', 'MURES'],
#  'VOIVODENI': [[46.7048038, 24.6256928], 'Vajdaszentivány', 'MURES'],
#  'DOBIRLAU': [[45.7377198, 25.8839772], 'Dobolló', 'COVASNA'],
#  'MALNAS': [[46.0077474, 25.8411026], 'Málnás', 'COVASNA'],
#  'GHIDFALAU': [[45.9, 25.85], 'Gidófalva', 'COVASNA'],
#  'VINATORI': [[46.241667, 24.925833], 'Héjjasfalva', 'MURES'],
#  'MUNICIPIUL TIRGU MURES': [[46.545556, 24.5625], 'Marosvásárhely', 'MURES'],
#  'MUNICIPIUL TOPLITA': [[46.92361100000001, 25.345833],
#   'Maroshévíz',
#   'HARGHITA'],
#  'GALESTI': [[46.5126617, 24.7566473], 'Nyárádgálfalva', 'MURES'],
#  'MUNICIPIUL GHEORGHENI': [[46.7212112, 25.5855274],
#   'Gyergyószentmiklós',
#   'HARGHITA'],
#  'ORAS BARAOLT': [[46.075, 25.6], 'Barót', 'COVASNA'],
#  'MAGHERANI': [[46.56426829999999, 24.9018318], 'Nyárádmagyarós', 'MURES'],
#  'FINTINELE': [[46.421745, 24.7657281], 'Gyulakuta', 'MURES'],
#  'DEDA': [[46.9486509, 24.875216], 'Déda', 'MURES'],
#  'SOLOVASTRU': [[46.7743869, 24.7703304], 'Görgényoroszfalu', 'MURES'],
#  'OGRA': [[46.4463465, 24.3221771], 'Marosugra', 'MURES'],
#  'ORAS CRISTURU SECUIESC': [[46.291667, 25.035278],
#   'Székelykeresztúr',
#   'HARGHITA'],
#  'PASARENI': [[46.4918128, 24.6943814], 'Backamadaras', 'MURES'],
#  'ORAS BAILE TUSNAD': [[46.14694100000001, 25.860563],
#   'Tusnádfürdõ',
#   'HARGHITA'],
#  'NADES': [[46.321389, 24.719167], 'Szásznádas', 'MURES'],
#  'GHELINTA': [[45.94098959999999, 26.2422934], 'Gelence', 'COVASNA'],
#  'GANESTI': [[46.3336531, 24.3588403], 'Vámosgálfalva', 'MURES'],
#  'MUNICIPIUL ODORHEIU SECUIESC': [[46.3049996, 25.2926479],
#   'Székelyudvarhely',
#   'HARGHITA'],
#  'CATALINA': [[45.96666700000001, 26.15], 'Szentkatolna', 'COVASNA'],
#  'SITA BUZAULUI': [[45.65, 26.066667], 'Bodzaszita', 'COVASNA'],
#  'LAZAREA': [[46.75, 25.533333], 'Gyergyószárhegy', 'HARGHITA'],
#  'STINCENI': [[46.9603377, 25.224312], 'Gödemesterháza', 'MURES'],
#  'CHETANI': [[46.46439609999999, 24.0256758], 'Maroskece', 'MURES'],
#  'SECUIENI': [[46.2608366, 24.9731894], 'Újszékely', 'HARGHITA'],
#  'CORBU': [[46.98333299999999, 25.7], 'Gyergyóholló', 'HARGHITA'],
#  'SINCRAIU DE MURES': [[46.55, 24.52], 'Marosszentkirály', 'MURES'],
#  'MIHAILENI': [[46.473248, 25.8285411], 'Csíkszentmihály', 'HARGHITA'],
#  'BALAUSERI': [[46.4078416, 24.6929815], 'Balavásár', 'MURES'],
#  'SIMONESTI': [[46.3372208, 25.1077262], 'Siménfalva', 'HARGHITA'],
#  'VOSLABENI': [[46.6445, 25.6229], 'Vasláb', 'HARGHITA'],
#  'BEICA DE JOS': [[46.73423589999999, 24.7967137], 'Alsóbölkény', 'MURES'],
#  'LUNCA': [[46.8494, 24.5772], 'Tekeújfalu', 'MURES'],
#  'CRISTESTI': [[46.5, 24.483333], 'Maroskeresztúr', 'MURES'],
#  'ZABALA': [[45.88770299999999, 26.189789], 'Zabola', 'COVASNA'],
#  'COMANDAU': [[45.7566467, 26.2730085], 'Kommandó', 'COVASNA'],
#  'PAULENI-CIUC': [[46.3948378, 25.8341045], 'Csíkpálfalva', 'HARGHITA'],
#  'RICIU': [[46.683333, 24.4], 'Mezõrücs', 'MURES'],
#  'DANES': [[46.222477, 24.7015179], 'Dános', 'MURES'],
#  'ORAS BORSEC': [[46.966667, 25.57], 'Borszék', 'HARGHITA'],
#  'VARGATA': [[46.5779759, 24.8009879], 'Csíkfalva', 'MURES'],
#  'SINPETRU DE CIMPIE': [[46.72, 24.27], 'Uzdiszentpéter', 'MURES'],
#  'ATINTIS': [[46.433333, 24.1], 'Cintos', 'MURES'],
#  'ICLANZEL': [[46.5251545, 24.2753069], 'Kisikland', 'MURES'],
#  'VARSAG': [[46.5090719, 25.3728074], 'Székelyvarság', 'HARGHITA'],
#  'SANMARTIN': [[46.266217, 25.9393672], 'Csíkszentmárton', 'HARGHITA'],
#  'DITRAU': [[46.816667, 25.516667], 'Gyergyóditró', 'HARGHITA'],
#  'CORUND': [[46.466667, 25.183333], 'Korond', 'HARGHITA'],
#  'ORAS BALAN': [[46.649722, 25.81], 'Balánbánya', 'HARGHITA'],
#  'GREBENISU DE CIMPIE': [[46.6069835, 24.3005392], 'Mezõgerebenes', 'MURES'],
#  'BODOC': [[45.95, 25.85], 'Sepsibodok', 'COVASNA'],
#  'COZMA': [[46.8101006, 24.5132102], 'Kozmatelke', 'MURES'],
#  'FELICENI': [[46.2743433, 25.2775321], 'Felsõboldogfalva', 'HARGHITA'],
#  'MUNICIPIUL TARNAVENI': [[46.3293137, 24.2935777],
#   'Dicsõszentmárton',
#   'MURES'],
#  'MUNICIPIUL SIGHISOARA': [[46.216944, 24.791111], 'Segesvár', 'MURES'],
#  'PETELEA': [[46.7294376, 24.7086784], 'Petele', 'MURES'],
#  'BELIN': [[45.933333, 25.566667], 'Bölön', 'COVASNA'],
#  'LUNCA DE SUS': [[46.5274474, 25.9579248], 'Gyimesfelsõlok', 'HARGHITA'],
#  'VETCA': [[46.3517282, 24.7899164], 'Székelyvécke', 'MURES'],
#  'REMETEA': [[46.783333, 25.45], 'Gyergyóremete', 'HARGHITA'],
#  'RUSII-MUNTI': [[46.91999999999999, 24.85], 'Marosoroszfalu', 'MURES'],
#  'BAHNEA': [[46.3714762, 24.4755115], 'Bonyha', 'MURES'],
#  'ORAS INTORSURA BUZAULUI': [[45.672778, 26.034167],
#   'Bodzaforduló',
#   'COVASNA'],
#  'COROISINMARTIN': [[46.40698709999999, 24.596485],
#   'Kóródszentmárton',
#   'MURES'],
#  'BRATES': [[45.8342844, 26.0706541], 'Barátos', 'COVASNA'],
#  'ALBESTI': [[46.23333299999999, 24.85], 'Fehéregyháza', 'MURES'],
#  'ZAU DE CIMPIE': [[46.6127595, 24.1267725], 'Mezõzáh', 'MURES'],
#  'BOGATA': [[46.453782, 24.118921], 'Marosbogát', 'MURES'],
#  'BARCANI': [[45.7, 26.083333], 'Zágonbárkány', 'COVASNA'],
#  'VALEA CRISULUI': [[45.9161216, 25.7755976], 'Sepsikõröspatak', 'COVASNA'],
#  'CIUMANI': [[46.6799973, 25.519454], 'Gyergyócsomafalva', 'HARGHITA'],
#  'CUCERDEA': [[46.4, 24.266667], 'Oláhkocsárd', 'MURES'],
#  'MUNICIPIUL TARGU SECUIESC': [[45.996944, 26.140556],
#   'Kézdivásárhely',
#   'COVASNA'],
#  'SANCRAIENI': [[46.313333, 25.839444], 'Csíkszentkirály', 'HARGHITA'],
#  'ORAS COVASNA': [[45.849167, 26.185278], 'Kovászna', 'COVASNA'],
#  'AITA MARE': [[45.96705720000001, 25.5635224], 'Nagyajta', 'COVASNA'],
#  'ADAMUS': [[46.304229, 24.2413007], 'Ádámos', 'MURES'],
#  'APOLD': [[46.1266596, 24.8196464], 'Apold', 'MURES'],
#  'SUBCETATE': [[46.85, 25.433333], 'Gyergyóvárhegy', 'HARGHITA'],
#  'BRINCOVENESTI': [[46.8570528, 24.757905], 'Marosvécs', 'MURES'],
#  'ORAS LUDUS': [[46.477778, 24.096111], 'Marosludas', 'MURES'],
#  'CRACIUNESTI': [[46.48, 24.58], 'Nyárádkarácson', 'MURES'],
#  'SUPLAC': [[46.3972736, 24.5189235], 'Küküllõszéplak', 'MURES'],
#  'ATID': [[46.4534697, 25.0478746], 'Etéd', 'HARGHITA'],
#  'SASCHIZ': [[46.1916099, 24.9615752], 'Szászkézd', 'MURES'],
#  'DANESTI': [[46.51666700000001, 25.75], 'Csíkdánfalva', 'HARGHITA'],
#  'ILIENI': [[45.792222, 25.771111], 'Illyefalva', 'COVASNA'],
#  'ORAS MIERCUREA NIRAJULUI': [[46.53, 24.8], 'Nyárádszereda', 'MURES'],
#  'LUPENI': [[46.379722, 25.225833], 'Farkaslaka', 'HARGHITA'],
#  'LEMNIA': [[46.05, 26.266667], 'Lemhény', 'COVASNA'],
#  'AVRAMESTI': [[46.334717, 25.0091156], 'Szentábrahám', 'HARGHITA'],
#  'ERNEI': [[46.6073568, 24.6425059], 'Nagyernye', 'MURES'],
#  'CARTA': [[46.5305691, 25.7615353], 'Csíkkarcfalva', 'HARGHITA'],
#  'BAGACIU': [[46.27, 24.37], 'Szászbogács', 'MURES'],
#  'VIISOARA': [[46.2936607, 24.5990424], 'Csatófalva', 'MURES'],
#  'PANET': [[46.55, 24.466667], 'Mezõpanit', 'MURES'],
#  'CRAIESTI': [[46.2975493, 24.1918792], 'Mezõkirályfalva', 'MURES'],
#  'BOROSNEU MARE': [[45.816667, 26], 'Nagyborosnyó', 'COVASNA'],
#  'PAPIU ILARIAN': [[46.5586506, 24.1972763], 'Mezõbodon', 'MURES']}

# %%
for m in megye:
    for j in coords[m]:
        if j in hun[m]:
            if j not in mindhu:
                mindhu[j]=[coords[m][j],hun[m][j],m]

# %%
mindhu
# Out:
# {'BALA': [[46.7121253, 24.4979748], 'Bala', 'MURES'],
#  'ZAGAR': [[46.3506, 24.6181], 'Zágor', 'MURES'],
#  'ORAS UNGHENI': [[46.485833, 24.460833], 'Nyárádtõ', 'MURES'],
#  'VALEA LARGA': [[46.62, 24.07], 'Mezõceked', 'MURES'],
#  'ULIES': [[46.2112783, 25.2420621], 'Kányád', 'HARGHITA'],
#  'MIHESU DE CIMPIE': [[46.68000000000001, 24.15], 'Mezõméhes', 'MURES'],
#  'HODOSA': [[46.6369073, 24.823399], 'Székelyhodos', 'MURES'],
#  'EREMITU': [[46.66098040000001, 24.9273587], 'Nyárádremete', 'MURES'],
#  'GLODENI': [[46.6549681, 24.6080416], 'Marossárpatak', 'MURES'],
#  'BRADESTI': [[46.34116119999999, 25.3407935], 'Fenyéd', 'HARGHITA'],
#  'MUNICIPIUL REGHIN': [[46.77583300000001, 24.708333], 'Szászrégen', 'MURES'],
#  'ORAS VLAHITA': [[46.35, 25.53], 'Szentegyháza', 'HARGHITA'],
#  'SINCAI': [[46.655366, 24.392263], 'Mezõsámsod', 'MURES'],
#  'PRAID': [[46.55, 25.133333], 'Parajd', 'HARGHITA'],
#  'IDECIU DE JOS': [[46.8154513, 24.7568272], 'Alsóidecs', 'MURES'],
#  'BICHIS': [[46.3753746, 24.0911289], 'Magyarbükkös', 'MURES'],
#  'MOACSA': [[45.866667, 25.966667], 'Maksa', 'COVASNA'],
#  'TUSNAD': [[46.2068655, 25.9119481], 'Tusnád', 'HARGHITA'],
#  'CEUASU DE CIMPIE': [[46.64040749999999, 24.5145836], 'Mezõcsávás', 'MURES'],
#  'PLAIESII DE JOS': [[46.22490819999999, 26.1004859],
#   'Kászonaltíz',
#   'HARGHITA'],
#  'ORAS SOVATA': [[46.596111, 25.074444], 'Szováta', 'MURES'],
#  'GHEORGHE DOJA': [[46.4635769, 24.5078157], 'Lukafalva', 'MURES'],
#  'FRUMOASA': [[46.45484, 25.8515132], 'Csíkszépvíz', 'HARGHITA'],
#  'OZUN': [[45.8, 25.85], 'Uzon', 'COVASNA'],
#  'JOSENI': [[46.7, 25.5], 'Gyergyóalfalu', 'HARGHITA'],
#  'POGACEAUA': [[46.6769566, 24.3080262], 'Mezõpagocsa', 'MURES'],
#  'MUNICIPIUL SFINTU GHEORGHE': [[45.863611, 25.7875],
#   'Sepsiszentgyörgy',
#   'COVASNA'],
#  'SINTANA DE MURES': [[46.57000000000001, 24.55], 'Marosszentanna', 'MURES'],
#  'LUETA': [[46.2747298, 25.4914355], 'Lövéte', 'HARGHITA'],
#  'CUCI': [[46.4634727, 24.1553106], 'Kutyfalva', 'MURES'],
#  'CHIHERU DE JOS': [[46.6861581, 24.8741279], 'Alsóköhér', 'MURES'],
#  'POIAN': [[46.0696927, 26.1598138], 'Kézdiszentkereszt', 'COVASNA'],
#  'CIUCSINGEORGIU': [[46.316667, 25.95], 'Csíkszentgyörgy', 'HARGHITA'],
#  'TAURENI': [[46.5798792, 24.082425], 'Mezõtóhát', 'MURES'],
#  'BRADUT': [[46.1289647, 25.6101146], 'Bardóc', 'COVASNA'],
#  'BAND': [[46.5762629, 24.3743048], 'Mezõbánd', 'MURES'],
#  'OCLAND': [[46.1628838, 25.4251311], 'Oklánd', 'HARGHITA'],
#  'FARAGAU': [[46.76348609999999, 24.5148013], 'Faragó', 'MURES'],
#  'MERESTI': [[46.2343918, 25.4569963], 'Homoródalmás', 'HARGHITA'],
#  'SACEL': [[46.3129807, 24.9298014], 'Székelyandrásfalva', 'HARGHITA'],
#  'SINGEORGIU DE MURES': [[46.5792435, 24.608682], 'Marosszentgyörgy', 'MURES'],
#  'BRETCU': [[46.04342459999999, 26.3028187], 'Bereck', 'COVASNA'],
#  'VILCELE': [[45.8537981, 25.6840786], 'Elõpatak', 'COVASNA'],
#  'BATANI': [[46.089444, 25.691389], 'Nagybacon', 'COVASNA'],
#  'SARMAS': [[46.8799773, 25.4549439], 'Salamás', 'HARGHITA'],
#  'HODAC': [[46.7769539, 24.9262556], 'Görgényhodák', 'MURES'],
#  'ORAS SARMASU': [[46.753611, 24.166667], 'Nagysármás', 'MURES'],
#  'BILBOR': [[47.0656143, 25.4864041], 'Bélbor', 'HARGHITA'],
#  'MUNICIPIUL MIERCUREA CIUC': [[46.358, 25.804], 'Csíkszereda', 'HARGHITA'],
#  'DIRJIU': [[46.2, 25.2], 'Székelyderzs', 'HARGHITA'],
#  'VATAVA': [[46.966667, 24.766667], 'Felsõrépás', 'MURES'],
#  'GORNESTI': [[46.6708485, 24.6507173], 'Gernyeszeg', 'MURES'],
#  'SICULENI': [[46.4374818, 25.7531516], 'Madéfalva', 'HARGHITA'],
#  'DEALU': [[46.3959239, 25.3039301], 'Oroszhegy', 'HARGHITA'],
#  'RASTOLITA': [[46.9733161, 24.9917231], 'Ratosnya', 'MURES'],
#  'ZETEA': [[46.383333, 25.366667], 'Zetelaka', 'HARGHITA'],
#  'ZAGON': [[45.766667, 26.116667], 'Zágon', 'COVASNA'],
#  'MUGENI': [[46.25703499999999, 25.2210098], 'Bögöz', 'HARGHITA'],
#  'RECI': [[45.8398226, 25.9229125], 'Réty', 'COVASNA'],
#  'BATOS': [[46.8865613, 24.6517966], 'Bátos', 'MURES'],
#  'NEAUA': [[46.47843290000001, 24.8301881], 'Havad', 'MURES'],
#  'HAGHIG': [[45.8391349, 25.5892157], 'Hídvég', 'COVASNA'],
#  'CHICHIS': [[45.7707805, 25.7997157], 'Kökös', 'COVASNA'],
#  'ORAS SANGEORGIU DE PADURE': [[46.43027800000001, 24.841667],
#   'Erdõszentgyörgy',
#   'MURES'],
#  'MICA': [[46.36722049999999, 24.4101129], 'Mikefalva', 'MURES'],
#  'CAPILNITA': [[46.3594353, 25.511701], 'Kápolnásfalu', 'HARGHITA'],
#  'VIRGHIS': [[45.9426347, 25.8918984], 'Vargyas', 'COVASNA'],
#  'ORAS IERNUT': [[46.453611, 24.233333], 'Radnót', 'MURES'],
#  'SAULIA': [[46.633333, 24.216667], 'Mezõsályi', 'MURES'],
#  'IBANESTI': [[46.7704043, 24.9322946], 'Libánfalva', 'MURES'],
#  'ACATARI': [[46.479789, 24.6353545], 'Ákosfalva', 'MURES'],
#  'GURGHIU': [[46.7687756, 24.8559776], 'Görgényszentimre', 'MURES'],
#  'LIVEZENI': [[46.55, 24.633333], 'Jedd', 'MURES'],
#  'TURIA': [[46.0512486, 26.0422425], 'Torja', 'COVASNA'],
#  'SUSENI': [[46.666667, 25.55], 'Gyergyóújfalu', 'HARGHITA'],
#  'ALUNIS': [[46.8941662, 24.8205851], 'Magyaró', 'MURES'],
#  'SINPAUL': [[46.45, 24.35], 'Kerelõszentpál', 'MURES'],
#  'LUNCA DE JOS': [[46.5711344, 25.9769607], 'Gyimesközéplok', 'HARGHITA'],
#  'GALAUTAS': [[46.912712, 25.4042124], 'Galócás', 'HARGHITA'],
#  'SINDOMINIC': [[46.583333, 25.783333], 'Csíkszentdomokos', 'HARGHITA'],
#  'SANGER': [[46.55, 24.13], 'Mezõszengyel', 'MURES'],
#  'GHINDARI': [[46.5054469, 24.9235061], 'Makfalva', 'MURES'],
#  'CERNAT': [[45.95, 26.033333], 'Csernáton', 'COVASNA'],
#  'TULGHES': [[46.9502975, 25.7568596], 'Gyergyótölgyes', 'HARGHITA'],
#  'SINZIENI': [[45.9426347, 25.8918984], 'Kézdiszentlélek', 'COVASNA'],
#  'OJDULA': [[45.98333299999999, 26.25], 'Ozsdola', 'COVASNA'],
#  'LUNCA BRADULUI': [[46.9589754, 25.1086962], 'Palotailva', 'MURES'],
#  'MARTINIS': [[46.23333299999999, 25.383333],
#   'Homoródszentmárton',
#   'HARGHITA'],
#  'BREAZA': [[46.7662233, 24.6378932], 'Beresztelke', 'MURES'],
#  'VOIVODENI': [[46.7048038, 24.6256928], 'Vajdaszentivány', 'MURES'],
#  'DOBIRLAU': [[45.7377198, 25.8839772], 'Dobolló', 'COVASNA'],
#  'MALNAS': [[46.0077474, 25.8411026], 'Málnás', 'COVASNA'],
#  'GHIDFALAU': [[45.9, 25.85], 'Gidófalva', 'COVASNA'],
#  'VINATORI': [[46.241667, 24.925833], 'Héjjasfalva', 'MURES'],
#  'MUNICIPIUL TIRGU MURES': [[46.545556, 24.5625], 'Marosvásárhely', 'MURES'],
#  'MUNICIPIUL TOPLITA': [[46.92361100000001, 25.345833],
#   'Maroshévíz',
#   'HARGHITA'],
#  'GALESTI': [[46.5126617, 24.7566473], 'Nyárádgálfalva', 'MURES'],
#  'MUNICIPIUL GHEORGHENI': [[46.7212112, 25.5855274],
#   'Gyergyószentmiklós',
#   'HARGHITA'],
#  'ORAS BARAOLT': [[46.075, 25.6], 'Barót', 'COVASNA'],
#  'MAGHERANI': [[46.56426829999999, 24.9018318], 'Nyárádmagyarós', 'MURES'],
#  'FINTINELE': [[46.421745, 24.7657281], 'Gyulakuta', 'MURES'],
#  'DEDA': [[46.9486509, 24.875216], 'Déda', 'MURES'],
#  'SOLOVASTRU': [[46.7743869, 24.7703304], 'Görgényoroszfalu', 'MURES'],
#  'OGRA': [[46.4463465, 24.3221771], 'Marosugra', 'MURES'],
#  'ORAS CRISTURU SECUIESC': [[46.291667, 25.035278],
#   'Székelykeresztúr',
#   'HARGHITA'],
#  'PASARENI': [[46.4918128, 24.6943814], 'Backamadaras', 'MURES'],
#  'ORAS BAILE TUSNAD': [[46.14694100000001, 25.860563],
#   'Tusnádfürdõ',
#   'HARGHITA'],
#  'NADES': [[46.321389, 24.719167], 'Szásznádas', 'MURES'],
#  'GHELINTA': [[45.94098959999999, 26.2422934], 'Gelence', 'COVASNA'],
#  'GANESTI': [[46.3336531, 24.3588403], 'Vámosgálfalva', 'MURES'],
#  'MUNICIPIUL ODORHEIU SECUIESC': [[46.3049996, 25.2926479],
#   'Székelyudvarhely',
#   'HARGHITA'],
#  'CATALINA': [[45.96666700000001, 26.15], 'Szentkatolna', 'COVASNA'],
#  'SITA BUZAULUI': [[45.65, 26.066667], 'Bodzaszita', 'COVASNA'],
#  'LAZAREA': [[46.75, 25.533333], 'Gyergyószárhegy', 'HARGHITA'],
#  'STINCENI': [[46.9603377, 25.224312], 'Gödemesterháza', 'MURES'],
#  'CHETANI': [[46.46439609999999, 24.0256758], 'Maroskece', 'MURES'],
#  'SECUIENI': [[46.2608366, 24.9731894], 'Újszékely', 'HARGHITA'],
#  'CORBU': [[46.98333299999999, 25.7], 'Gyergyóholló', 'HARGHITA'],
#  'SINCRAIU DE MURES': [[46.55, 24.52], 'Marosszentkirály', 'MURES'],
#  'MIHAILENI': [[46.473248, 25.8285411], 'Csíkszentmihály', 'HARGHITA'],
#  'BALAUSERI': [[46.4078416, 24.6929815], 'Balavásár', 'MURES'],
#  'SIMONESTI': [[46.3372208, 25.1077262], 'Siménfalva', 'HARGHITA'],
#  'VOSLABENI': [[46.6445, 25.6229], 'Vasláb', 'HARGHITA'],
#  'BEICA DE JOS': [[46.73423589999999, 24.7967137], 'Alsóbölkény', 'MURES'],
#  'LUNCA': [[46.8494, 24.5772], 'Tekeújfalu', 'MURES'],
#  'CRISTESTI': [[46.5, 24.483333], 'Maroskeresztúr', 'MURES'],
#  'ZABALA': [[45.88770299999999, 26.189789], 'Zabola', 'COVASNA'],
#  'COMANDAU': [[45.7566467, 26.2730085], 'Kommandó', 'COVASNA'],
#  'PAULENI-CIUC': [[46.3948378, 25.8341045], 'Csíkpálfalva', 'HARGHITA'],
#  'RICIU': [[46.683333, 24.4], 'Mezõrücs', 'MURES'],
#  'DANES': [[46.222477, 24.7015179], 'Dános', 'MURES'],
#  'ORAS BORSEC': [[46.966667, 25.57], 'Borszék', 'HARGHITA'],
#  'VARGATA': [[46.5779759, 24.8009879], 'Csíkfalva', 'MURES'],
#  'SINPETRU DE CIMPIE': [[46.72, 24.27], 'Uzdiszentpéter', 'MURES'],
#  'ATINTIS': [[46.433333, 24.1], 'Cintos', 'MURES'],
#  'ICLANZEL': [[46.5251545, 24.2753069], 'Kisikland', 'MURES'],
#  'VARSAG': [[46.5090719, 25.3728074], 'Székelyvarság', 'HARGHITA'],
#  'SANMARTIN': [[46.266217, 25.9393672], 'Csíkszentmárton', 'HARGHITA'],
#  'DITRAU': [[46.816667, 25.516667], 'Gyergyóditró', 'HARGHITA'],
#  'CORUND': [[46.466667, 25.183333], 'Korond', 'HARGHITA'],
#  'ORAS BALAN': [[46.649722, 25.81], 'Balánbánya', 'HARGHITA'],
#  'GREBENISU DE CIMPIE': [[46.6069835, 24.3005392], 'Mezõgerebenes', 'MURES'],
#  'BODOC': [[45.95, 25.85], 'Sepsibodok', 'COVASNA'],
#  'COZMA': [[46.8101006, 24.5132102], 'Kozmatelke', 'MURES'],
#  'FELICENI': [[46.2743433, 25.2775321], 'Felsõboldogfalva', 'HARGHITA'],
#  'MUNICIPIUL TARNAVENI': [[46.3293137, 24.2935777],
#   'Dicsõszentmárton',
#   'MURES'],
#  'MUNICIPIUL SIGHISOARA': [[46.216944, 24.791111], 'Segesvár', 'MURES'],
#  'PETELEA': [[46.7294376, 24.7086784], 'Petele', 'MURES'],
#  'BELIN': [[45.933333, 25.566667], 'Bölön', 'COVASNA'],
#  'LUNCA DE SUS': [[46.5274474, 25.9579248], 'Gyimesfelsõlok', 'HARGHITA'],
#  'VETCA': [[46.3517282, 24.7899164], 'Székelyvécke', 'MURES'],
#  'REMETEA': [[46.783333, 25.45], 'Gyergyóremete', 'HARGHITA'],
#  'RUSII-MUNTI': [[46.91999999999999, 24.85], 'Marosoroszfalu', 'MURES'],
#  'BAHNEA': [[46.3714762, 24.4755115], 'Bonyha', 'MURES'],
#  'ORAS INTORSURA BUZAULUI': [[45.672778, 26.034167],
#   'Bodzaforduló',
#   'COVASNA'],
#  'COROISINMARTIN': [[46.40698709999999, 24.596485],
#   'Kóródszentmárton',
#   'MURES'],
#  'BRATES': [[45.8342844, 26.0706541], 'Barátos', 'COVASNA'],
#  'ALBESTI': [[46.23333299999999, 24.85], 'Fehéregyháza', 'MURES'],
#  'ZAU DE CIMPIE': [[46.6127595, 24.1267725], 'Mezõzáh', 'MURES'],
#  'BOGATA': [[46.453782, 24.118921], 'Marosbogát', 'MURES'],
#  'BARCANI': [[45.7, 26.083333], 'Zágonbárkány', 'COVASNA'],
#  'VALEA CRISULUI': [[45.9161216, 25.7755976], 'Sepsikõröspatak', 'COVASNA'],
#  'CIUMANI': [[46.6799973, 25.519454], 'Gyergyócsomafalva', 'HARGHITA'],
#  'CUCERDEA': [[46.4, 24.266667], 'Oláhkocsárd', 'MURES'],
#  'MUNICIPIUL TARGU SECUIESC': [[45.996944, 26.140556],
#   'Kézdivásárhely',
#   'COVASNA'],
#  'SANCRAIENI': [[46.313333, 25.839444], 'Csíkszentkirály', 'HARGHITA'],
#  'ORAS COVASNA': [[45.849167, 26.185278], 'Kovászna', 'COVASNA'],
#  'AITA MARE': [[45.96705720000001, 25.5635224], 'Nagyajta', 'COVASNA'],
#  'ADAMUS': [[46.304229, 24.2413007], 'Ádámos', 'MURES'],
#  'APOLD': [[46.1266596, 24.8196464], 'Apold', 'MURES'],
#  'SUBCETATE': [[46.85, 25.433333], 'Gyergyóvárhegy', 'HARGHITA'],
#  'BRINCOVENESTI': [[46.8570528, 24.757905], 'Marosvécs', 'MURES'],
#  'ORAS LUDUS': [[46.477778, 24.096111], 'Marosludas', 'MURES'],
#  'CRACIUNESTI': [[46.48, 24.58], 'Nyárádkarácson', 'MURES'],
#  'SUPLAC': [[46.3972736, 24.5189235], 'Küküllõszéplak', 'MURES'],
#  'ATID': [[46.4534697, 25.0478746], 'Etéd', 'HARGHITA'],
#  'SASCHIZ': [[46.1916099, 24.9615752], 'Szászkézd', 'MURES'],
#  'DANESTI': [[46.51666700000001, 25.75], 'Csíkdánfalva', 'HARGHITA'],
#  'ILIENI': [[45.792222, 25.771111], 'Illyefalva', 'COVASNA'],
#  'ORAS MIERCUREA NIRAJULUI': [[46.53, 24.8], 'Nyárádszereda', 'MURES'],
#  'LUPENI': [[46.379722, 25.225833], 'Farkaslaka', 'HARGHITA'],
#  'LEMNIA': [[46.05, 26.266667], 'Lemhény', 'COVASNA'],
#  'AVRAMESTI': [[46.334717, 25.0091156], 'Szentábrahám', 'HARGHITA'],
#  'ERNEI': [[46.6073568, 24.6425059], 'Nagyernye', 'MURES'],
#  'CARTA': [[46.5305691, 25.7615353], 'Csíkkarcfalva', 'HARGHITA'],
#  'BAGACIU': [[46.27, 24.37], 'Szászbogács', 'MURES'],
#  'VIISOARA': [[46.2936607, 24.5990424], 'Csatófalva', 'MURES'],
#  'PANET': [[46.55, 24.466667], 'Mezõpanit', 'MURES'],
#  'CRAIESTI': [[46.2975493, 24.1918792], 'Mezõkirályfalva', 'MURES'],
#  'BOROSNEU MARE': [[45.816667, 26], 'Nagyborosnyó', 'COVASNA'],
#  'PAPIU ILARIAN': [[46.5586506, 24.1972763], 'Mezõbodon', 'MURES'],
#  'DARJIU': [[25.19888579679448, 46.200731637316544],
#   'Székelyderzs',
#   'HARGHITA'],
#  'SANDOMINIC': [[25.79305267434984, 46.57932853945138],
#   'Csíkszentdomokos',
#   'HARGHITA'],
#  'SANSIMION': [[25.88607622284845, 46.258253665765594],
#   'Csíkszentsimon',
#   'HARGHITA'],
#  'CAPALNITA': [[25.515146340172105, 46.36046683932412],
#   'Kápolnásfalu',
#   'HARGHITA'],
#  'CIUCSANGEORGIU': [[25.95661584573873, 46.32201794449954],
#   'Csíkszentgyörgy',
#   'HARGHITA'],
#  'VARGHIS': [[25.559009047846857, 46.127370493896635], 'Vargyas', 'COVASNA'],
#  'VALEA MARE': [[26.01434688233875, 45.76388983145247],
#   'Nagypatak',
#   'COVASNA'],
#  'MUNICIPIUL SFANTU GHEORGHE': [[25.788051367951184, 45.864662130170366],
#   'Sepsiszentgyörgy',
#   'COVASNA'],
#  'VALCELE': [[25.688381978432577, 45.854705691651795], 'Előpatak', 'COVASNA'],
#  'SANZIENI': [[26.130474447621154, 46.04455273688578],
#   'Kézdiszentlélek',
#   'COVASNA'],
#  'DOBARLAU': [[25.88628497423985, 45.738318685060946], 'Dobolló', 'COVASNA'],
#  'ZAU DE CAMPIE': [[24.13080421457399, 46.61382498820179], 'Mezőzáh', 'MURES'],
#  'SANGEORGIU DE PADURE': [[24.84274492719636, 46.43061241918186],
#   'Erdőszentgyörgy',
#   'MURES'],
#  'VANATORI': [[24.928203341861273, 46.24241871920987], 'Héjjasfalva', 'MURES'],
#  'MIERCUREA NIRAJULUI': [[24.808462203121465, 46.5364299657112],
#   'Nyárádszereda',
#   'MURES'],
#  'SANGEORGIU DE MURES': [[24.608249798030094, 46.57694278773338],
#   'Marosszentgyörgy',
#   'MURES'],
#  'GREBENISU DE CAMPIE': [[24.311713345673365, 46.60880569640315],
#   'Mezőgerebenes',
#   'MURES'],
#  'FANTANELE': [[24.76653617766271, 46.42181757281516], 'Gyulakuta', 'MURES'],
#  'SANTANA DE MURES': [[24.556633212592306, 46.57658432734983],
#   'Marosszentanna',
#   'MURES'],
#  'CEUASU DE CAMPIE': [[24.513870708284024, 46.64293152939656],
#   'Mezőcsávás',
#   'MURES'],
#  'MIHESU DE CAMPIE': [[24.158664491017795, 46.677655720583545],
#   'Mezőméhes',
#   'MURES'],
#  'STANCENI': [[25.23921161986209, 46.9601847968545],
#   'Gödemesterháza',
#   'MURES'],
#  'SANCRAIU DE MURES': [[24.547213082096395, 46.55916385431674],
#   'Marosszentkirály',
#   'MURES'],
#  'SARMASU': [[24.164722124641994, 46.75323496970526], 'Nagysármás', 'MURES'],
#  'COROISANMARTIN': [[24.60201917615332, 46.40747188113697],
#   'Kóródszentmárton',
#   'MURES'],
#  'SANPAUL': [[24.35133243843079, 46.4564575327875], 'Kerelőszentpál', 'MURES'],
#  'UNGHENI': [[24.458808585305533, 46.48572727326162], 'Nyárádtő', 'MURES'],
#  'BRANCOVENESTI': [[24.759910515004098, 46.85593631343276],
#   'Marosvécs',
#   'MURES'],
#  'MUNICIPIUL TARGU MURES': [[24.55978132456377, 46.540506175821584],
#   'Marosvásárhely',
#   'MURES'],
#  'RACIU': [[24.39699805182019, 46.69019158853461], 'Mezőrücs', 'MURES'],
#  'SANPETRU DE CAMPIE': [[24.262428467169194, 46.71588771950704],
#   'Uzdiszentpéter',
#   'MURES']}

# %%
for m in megye:
    for j in coords[m]:
        if j not in hun[m]:
            print(m,j)
# Out:
# HARGHITA NICOLENI
# HARGHITA MORARENI
# HARGHITA GHEORGHENI
# HARGHITA CALONDA
# HARGHITA IASU
# HARGHITA SOIMENI
# HARGHITA MEDISORU MARE
# HARGHITA CHILENI
# HARGHITA SICASAU
# HARGHITA ARMASENII NOI
# HARGHITA PINTIC
# HARGHITA COTORMANI
# HARGHITA BORSEC
# HARGHITA SATU MARE
# HARGHITA SANCRAI
# HARGHITA BALAN
# HARGHITA VALEA CAPELEI
# HARGHITA OCNA DE JOS
# HARGHITA CHEDIA MARE
# MURES ROTENI
# MURES ROUA

# %% [markdown]
# Full geocode re-run

# %%
df=pd.read_csv('magyar.csv',sep='|')

# %%
from pygeocoder import Geocoder
apikey='AIzaSyB7joM_loHFb1SYFJevWfMmBCD9VO2uykc'

# %%
df.columns
# Out:
# Index(['falu', 'megye', 'hun'], dtype='object')

# %%
hun_geo={}

# %%
errors=[]

# %%
for i in df.index:
    falu=df.loc[i]['falu']
    megye=str(df.loc[i]['megye'])
    if falu=='Mihai Viteazu, Alsó- és Felsőszentmihály ':
        falu='Felsőszentmihály'
        megye='Felsőszentmihály, CJ'
    if megye=='Oras intorsura ':megye='Oras intorsura, CV'
    if megye=='Municipiul Brasov':megye='Municipiul Brasov, BV'
    if megye=='Municipiul Resita CS':megye='Municipiul Resita, CS'
    if megye=='Sanmihaiu de ':megye='Sanmihaiu de Campie, BN'
        
    if falu not in ['Buzaului, CV','Csegőd + Horindzsapuszta + Irtáspuszta','I. G. Duca = Plopi',
                   'meggyesi rét','Parau-tepeseni, Bicazu Ardelean ','Ardelean, NT','Campie, BN',
                   'Sajómagyarósi völgy','Gábor Áron vasüzem']:
        if megye not in ['Mihai Viteazu, CJ']:
            kozseg, m=megye.split(',')
            hun=df.loc[i]['hun']
            to_geo=falu+', '+megye+', Romania'
            if hun not in hun_geo:
                try:
                    coords=Geocoder(apikey).geocode(to_geo).coordinates
                except: 
                    errors.append(df.loc[i])
                print(i)
                hun_geo[hun]={'coords':coords,'falu':falu,'kozseg':kozseg, 'megye':m}
# Out:
# 5957
# 5958
# 5959
# 5960
# 5961
# 5962
# 5963
# 5964
# 5965
# 5966
# 5967
# 5968
# 5969
# 5970
# 5971
# 5972
# 5973
# 5974
# 5975
# 5976
# 5977
# 5980
# 5981
# 5982
# 5983
# 5984
# 5985
# 5986
# 5987
# 5988
# 5989
# 5990
# 5991
# 5992
# 5993
# 5994
# 5995
# 5996
# 5997
# 5998
# 5999
# 6000
# 6002
# 6003
# 6006
# 6007
# 6008
# 6009
# 6011
# 6012
# 6013
# 6015
# 6016
# 6017
# 6018
# 6019
# 6022
# 6023
# 6024
# 6025
# 6026
# 6027
# 6028
# 6029
# 6030
# 6031
# 6032
# 6033
# 6034
# 6035
# 6036
# 6037
# 6038
# 6039
# 6040
# 6041
# 6044
# 6045
# 6048
# 6049
# 6051
# 6052
# 6053

# %%
open('hun_geo.json','w').write(json.dumps(hun_geo))
# Out:
# 601514

# %%
import numpy as np

# %%
for i in hun_geo:
    for j in ['falu', 'kozseg', 'megye']:
        hun_geo[i][j]=hun_geo[i][j].strip()

# %%
huncoords={}
for i in hun_geo:
    huncoords[str(i).strip()]=hun_geo[i]['coords']

# %%
open('huncoords.json','w').write(json.dumps(huncoords))
# Out:
# 229201

# %%
def get_megye(cd):
    megyek={'HR':'Hargita',
    'CV':'Kovászna',
    'MS':'Maros',
    'BV':'Brassó',
    'NT':'Neamț'}
    if cd in megyek:return megyek[cd]
    else:return 'Más megye'
m_geo={}
for i in hun_geo:
    megye=get_megye(hun_geo[i]['megye'])
    if megye not in m_geo:m_geo[megye]=[]
    m_geo[megye].append(str(i).strip())
for i in m_geo:
    m_geo[i]=np.sort(m_geo[i])

# %%
m_geo.keys()
# Out:
# dict_keys(['Más megye', 'Maros', 'Brassó', 'Kovászna', 'Hargita', 'Neamț'])

# %%
s=''
for m in ['Hargita', 'Kovászna', 'Maros', 'Brassó', 'Neamț', 'Más megye']:
    s+='\n'+m
    for f in m_geo[m]:
        s+='\n '+f
s+=' Más település'

# %%
open('droplist.txt','w',encoding='utf8').write(s)
# Out:
# 58274

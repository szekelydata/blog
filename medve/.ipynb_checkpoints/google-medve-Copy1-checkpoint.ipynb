# %%
# !pip install google
# Out:
# Requirement already satisfied: google in c:\users\csala\appdata\local\continuum\anaconda2\envs\python3\lib\site-packages (2.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\csala\appdata\local\continuum\anaconda2\envs\python3\lib\site-packages (from google) (4.6.3)
# cachecontrol 0.12.3 requires msgpack-python, which is not installed.
# tensorflow-tensorboard 1.5.1 has requirement bleach==1.5.0, but you'll have bleach 2.1.4 which is incompatible.
# tensorflow-tensorboard 1.5.1 has requirement html5lib==0.9999999, but you'll have html5lib 1.0.1 which is incompatible.
# tensorboard 1.8.0 has requirement bleach==1.5.0, but you'll have bleach 2.1.4 which is incompatible.
# tensorboard 1.8.0 has requirement html5lib==0.9999999, but you'll have html5lib 1.0.1 which is incompatible.
# docker-py 1.10.3 has requirement requests<2.11,>=2.5.2, but you'll have requests 2.19.1 which is incompatible.
# You are using pip version 18.0, however version 18.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %% [markdown]
# Automate Google using https://www.geeksforgeeks.org/performing-google-search-using-python-code/

# %%
# Get the first 5 hits for "google 1.9.1 python" in Google Pakistan
from googlesearch import search

for url in search('medve site:maszol.ro', tld='ro', lang='hu', stop=15):
    print(url)
# Out:
# http://www.maszol.ro/index.php/cimke/medvet%C3%A1mad%C3%A1s
# http://www.maszol.ro/index.php/szajtato/82476-mar-fenyes-nappal-is-emberre-tamad-a-medve-hargita-megyeben
# http://www.maszol.ro/index.php/tarsadalom/71521-a-medve-ne-legyen-vedett-allat-hargita-megyeben-javasolja-borboly-csaba
# http://www.maszol.ro/index.php/tarsadalom/101201-ennyiszer-tevedt-be-a-medve-a-szekelyfoldi-telepulesekre-az-elmult-ket-honapban
# http://www.maszol.ro/index.php/szajtato/77903-kitort-a-karamjabol-egy-allatkerti-medve
# http://www.maszol.ro/index.php/tarsadalom/101044-egyszerre-harom-medve-bukkant-fel-csikszeredaban
# http://www.maszol.ro/index.php/tarsadalom/100414-maros-megyeben-pusztitott-a-medve
# http://www.maszol.ro/index.php/tarsadalom/103884-szeben-megye-egy-nagytest-medve-rohangalt-az-emberek-kozott
# http://www.maszol.ro/index.php/szajtato/100857-kisgyermekes-csalad-kert-vedelmet-abasfalvan-a-hatosagoktol-a-medve-miatt
# http://www.maszol.ro/index.php/szajtato/101474-a-csend-rok-segitseget-kertek-a-medve-altal-megkergetett-turistak
# http://www.maszol.ro/index.php/szajtato/100652-behatolt-egy-medve-egy-csikszeredai-haz-majd-egy-iskola-udvarara
# http://www.maszol.ro/index.php/tarsadalom/99561-medveterkep-keszult-sepsiszentgyorgyon-arkoson-csapdaba-fognak-a-nagyvadat
# http://www.maszol.ro/index.php/tarsadalom/100659-maros-megyeben-minden-harmadik-nap-kart-okoz-a-medve
# http://www.maszol.ro/index.php/szajtato/103232-hazasparra-tamadt-a-medve-a-ferj-fejszevel-utott-az-allat-fejere
# http://www.maszol.ro/index.php/tarsadalom/100284-most-mar-nincs-is-olyan-este-amikor-ne-torne-be-valahova-a-medve
# http://www.maszol.ro/index.php/cimke/medve
# http://www.maszol.ro/index.php/eletmod/103089-nehany-jo-tanacs-mit-tegyen-ha-jon-a-medve
# http://www.maszol.ro/index.php/szajtato/98605-mar-arad-megyeben-is-felbukkant-egy-medve
# http://www.maszol.ro/index.php/tarsadalom/100646-tehenet-pusztitott-a-medve-bukklokan
# http://www.maszol.ro/index.php/tarsadalom/99071-kutyasetaltatora-tamadt-a-medve-tusnadfurd-n
# http://www.maszol.ro/index.php/tarsadalom/100467-nyolc-haszonallatot-pusztitott-el-a-medve-marosvasarhely-kozeleben

# %% [markdown]
# Custom search engine way https://cse.google.com/cse/create/new

# %%
# !pip install google-search-results
# Out:
# Collecting google-search-results
#   Downloading https://files.pythonhosted.org/packages/48/c2/4767ac10b0b783b9c4d9abeba4bc10b46d0da655de0bd55c6e2b1bddf8dd/google_search_results-1.2.4.tar.gz
# Requirement already satisfied: requests in c:\users\csala\appdata\local\continuum\anaconda2\envs\python3\lib\site-packages (from google-search-results) (2.19.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\csala\appdata\local\continuum\anaconda2\envs\python3\lib\site-packages (from requests->google-search-results) (3.0.4)
# Requirement already satisfied: urllib3<1.24,>=1.21.1 in c:\users\csala\appdata\local\continuum\anaconda2\envs\python3\lib\site-packages (from requests->google-search-results) (1.23)
# Requirement already satisfied: idna<2.8,>=2.5 in c:\users\csala\appdata\local\continuum\anaconda2\envs\python3\lib\site-packages (from requests->google-search-results) (2.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\csala\appdata\local\continuum\anaconda2\envs\python3\lib\site-packages (from requests->google-search-results) (2018.8.24)
# Building wheels for collected packages: google-search-results
#   Running setup.py bdist_wheel for google-search-results: started
#   Running setup.py bdist_wheel for google-search-results: finished with status 'done'
#   Stored in directory: C:\Users\csala\AppData\Local\pip\Cache\wheels\25\2b\92\d60deb1477b33f064ba9dedf7b7e1e5a1645f5629107f41f7a
# Successfully built google-search-results
# Installing collected packages: google-search-results
# Successfully installed google-search-results-1.2.4
# cachecontrol 0.12.3 requires msgpack-python, which is not installed.
# tensorflow-tensorboard 1.5.1 has requirement bleach==1.5.0, but you'll have bleach 2.1.4 which is incompatible.
# tensorflow-tensorboard 1.5.1 has requirement html5lib==0.9999999, but you'll have html5lib 1.0.1 which is incompatible.
# tensorboard 1.8.0 has requirement bleach==1.5.0, but you'll have bleach 2.1.4 which is incompatible.
# tensorboard 1.8.0 has requirement html5lib==0.9999999, but you'll have html5lib 1.0.1 which is incompatible.
# docker-py 1.10.3 has requirement requests<2.11,>=2.5.2, but you'll have requests 2.19.1 which is incompatible.
# You are using pip version 18.0, however version 18.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
from lib.google_search_results import GoogleSearchResults

params = {
    "q" : "Coffee",
    "location" : "Austin, Texas, United States",
    "hl" : "en",
    "gl" : "us",
    "google_domain" : "google.com",
    "api_key" : "demo",
}

query = GoogleSearchResults(params)
dictionary_results = query.get_dictionary()

# %%
dictionary_results
# Out:
# {'search_metadata': {'id': '5bdb8ee467ccdc083fe5ae74',
#   'status': 'Cached',
#   'created_at': '2018-11-01 23:40:20 UTC',
#   'processed_at': '2018-11-01 23:40:21 UTC',
#   'google_url': 'https://www.google.com/search?q=Coffee&oq=Coffee&uule=w+CAIQICIaQXVzdGluLFRleGFzLFVuaXRlZCBTdGF0ZXM&hl=en&gl=us&sourceid=chrome&ie=UTF-8',
#   'total_time_taken': 8.48},
#  'search_parameters': {'query': 'Coffee',
#   'location_requested': 'Austin, Texas, United States',
#   'location_used': 'Austin,Texas,United States',
#   'google_domain': 'google.com',
#   'hl': 'en',
#   'gl': 'us',
#   'device': 'desktop'},
#  'search_information': {'total_results': 1860000000,
#   'time_taken_displayed': 0.69,
#   'query_displayed': 'Coffee'},
#  'local_map': {'link': 'https://www.google.com/search?gl=us&hl=en&q=Coffee&npsic=0&rflfq=1&rldoc=1&rlha=0&rllag=30266699,-97743191,230&tbm=lcl&sa=X&ved=2ahUKEwjn5s2Mr7TeAhUBOK0KHaDjAcQQtgN6BAgAEAQ',
#   'gps_coordinates': {'latitude': 30.266699,
#    'longitude': -97.743191,
#    'altitude': 230},
#   'image': 'https://www.google.com/maps/vt/data=epHGY0x9gqUPnnBS5MIdFYJtCPNNslL-Xk9Q7pQWbN5nGV6WvyMW9XIRS8XwUfwJPSc3K0OQ5k52x_eJCjEnWiLdVw79OcaRXo_yhW1n8fHLKofobCAoXSMX56haxlmGPtmIPghebVaiE4XKro9fLZppDLarFSnMuTkfcssg90ir2oOx5A9jPrb9i12nfbD3cMdEI9kKTWz4Jvr4CjCf6q94_MuJOPGIreNE1R5-LhODfwuNYKQQgve8UHCjQvPVJPmVfYOddZ3qVS2mmTTSBQljXNmUOg3Rev6FjIdoPdMFX95TONfEQ77nKaCapodONbX8eCxZ-uttzAPCzECxn-I4Ov4NfdLjySU4sw0vPJ3ZwN00vEAhNXYt1Aynq6UKzcj8qPtsdM3_NqVwio87nc4G2YKqD1dVyTk-rffqlExJguQiaWzj2MyEkzFlL-G7Qlrs70OE5FKjEHdBPDWeipdo-4jGR9qLk-OUIAQGVMonGTAQfWWurbhF-zdba8IPGAt8PfQbBa5EHOcycD6vWJX1ErOECqVh3e-216yt-l6MtrkkO8JNsnKUPd89n6B6mLfF21zAPuhPkW-uJbTMgjeoSJiTkfQ7OigXhXwWO_2jCh354B1EludWtxln8YdYw3c4jFypnQhDjsQgV21JXiU8KtQRxCGlRJ31We-Mz6foGYsalSsUq7P13RJZ5f8fmJJDwgRicHW5205tPI92cml-teOAIegR9aMfa7HW9wtoEGjZugUHU-XMActGKGCS55TZ8FY1eMhsG61YQ0hopIfG0-lgpI2ilEL52vnNkdG8HsTAyvM8zpqBEPr6BHg9lhe0VIoDOkdtpeQVAdHAuGC3_MaEyXlmcaqOZ3nd7QlB3p3S_zOG1CizBMJdSuC2VSCE1gQytnmBqYbcDUto5Rz2DkElDPSIX7PcNytE1BtnoPmDeviremuL3uGpMDwb7fU8N7m3UkpesFXbyRRDRNn17ig3uT1vxfVPZc2T_fvhD1a2SGkjI9E5icBrgtm_fbhgQU2AvB4s6WzC1nfXbaXlYZD5VcSLP_Q'},
#  'local_results': [{'position': 1,
#    'title': 'Houndstooth Coffee',
#    'reviews': 431,
#    'price': '$',
#    'type': 'Coffee Shop',
#    'address': '401 Congress Ave #100c',
#    'description': 'Cozy hangout for carefully sourced brews',
#    'hours': 'Closes soon ⋅ 7PM',
#    'thumbnail': '...'},
#   {'position': 2,
#    'title': 'The Hideout Coffee House',
#    'reviews': 193,
#    'price': '$',
#    'type': 'Coffee Shop',
#    'address': '617 Congress Ave',
#    'description': 'Area institution with a theater upstairs',
#    'extensions': ['Quick bite', 'Fast service', 'Great dessert'],
#    'thumbnail': '...'},
#   {'position': 3,
#    'title': 'Caffe Medici',
#    'reviews': 360,
#    'price': '$',
#    'type': 'Coffee Shop',
#    'address': '200 Congress Ave',
#    'description': 'Neighborhood coffee house',
#    'hours': 'Closes soon ⋅ 7PM',
#    'thumbnail': '...'}],
#  'knowledge_graph': {'title': 'Coffee',
#   'image': '...',
#   'description': 'Coffee is a brewed drink prepared from roasted coffee beans, the seeds of berries from certain Coffea species. The genus Coffea is native to tropical Africa and Madagascar, the Comoros, Mauritius, and Réunion in the Indian Ocean.',
#   'source': {'name': 'Wikipedia',
#    'link': 'https://en.wikipedia.org/wiki/Coffee'},
#   'people_also_search_for': [{'name': 'Tea & Infusions',
#     'link': 'https://www.google.com/search?gl=us&hl=en&q=Tea&stick=H4sIAAAAAAAAAONgFuLUz9U3MCorTMtV4gAxzZNzKrQE_UpLijJLMvPzgjNTUssTK4sByyY5qioAAAA&sa=X&ved=2ahUKEwjn5s2Mr7TeAhUBOK0KHaDjAcQQxA0wInoECAQQBQ',
#     'source': 'foodfood',
#     'image': '...'},
#    {'name': 'Espresso',
#     'link': 'https://www.google.com/search?gl=us&hl=en&q=Espresso&stick=H4sIAAAAAAAAAONgFuLUz9U3MCorTMtV4gAxk0vSsrUE_UpLijJLMvPzgjNTUssTK4sBwYKq7CoAAAA&sa=X&ved=2ahUKEwjn5s2Mr7TeAhUBOK0KHaDjAcQQxA0wInoECAQQBw',
#     'source': 'foodfood',
#     'image': '...'},
#    {'name': 'Chocolate',
#     'link': 'https://www.google.com/search?gl=us&hl=en&q=Chocolate&stick=H4sIAAAAAAAAAONgFuLUz9U3MCorTMtV4gAzDcpytAT9SkuKMksy8_OCM1NSyxMriwHR8y5PKgAAAA&sa=X&ved=2ahUKEwjn5s2Mr7TeAhUBOK0KHaDjAcQQxA0wInoECAQQCQ',
#     'source': 'foodfood',
#     'image': '...'},
#    {'name': 'Cappuccino',
#     'link': 'https://www.google.com/search?gl=us&hl=en&q=Cappuccino&stick=H4sIAAAAAAAAAONgFuLUz9U3MCorTMtV4gAxLc0NjLQE_UpLijJLMvPzgjNTUssTK4sB6b-xkioAAAA&sa=X&ved=2ahUKEwjn5s2Mr7TeAhUBOK0KHaDjAcQQxA0wInoECAQQCw',
#     'source': 'foodfood',
#     'image': '...'},
#    {'name': 'Sugar',
#     'link': 'https://www.google.com/search?gl=us&hl=en&q=Sugar&stick=H4sIAAAAAAAAAONgFuLUz9U3MCorTMtV4gAxzSpMkrUE_UpLijJLMvPzgjNTUssTK4sBKGvFUCoAAAA&sa=X&ved=2ahUKEwjn5s2Mr7TeAhUBOK0KHaDjAcQQxA0wInoECAQQDQ',
#     'source': 'foodfood',
#     'image': '...'},
#    {'name': 'Latte',
#     'link': 'https://www.google.com/search?gl=us&hl=en&q=Latte&stick=H4sIAAAAAAAAAONgFuLUz9U3MCorTMtVAjMN84pMzbQE_UpLijJLMvPzgjNTUssTK4sBjSmgBisAAAA&sa=X&ved=2ahUKEwjn5s2Mr7TeAhUBOK0KHaDjAcQQxA0wInoECAQQDw',
#     'source': 'foodfood',
#     'image': '...'}],
#   'people_also_search_for_link': 'https://www.google.com/search?gl=us&hl=en&q=Coffee&stick=H4sIAAAAAAAAAONgFuLUz9U3MCorTMtVQjC1xLKTrfTT8vNTwIRVcWZKanliZTEAKVBbezAAAAA&sa=X&ved=2ahUKEwjn5s2Mr7TeAhUBOK0KHaDjAcQQMSgAMCJ6BAgEEAE',
#   'list': {'total_fat': ['0 g', '0%'],
#    'saturated_fat': ['0 g', '0%'],
#    'polyunsaturated_fat': ['0 g'],
#    'monounsaturated_fat': ['0 g'],
#    'trans_fat': ['0 g'],
#    'cholesterol': ['0 mg', '0%'],
#    'sodium': ['5 mg', '0%'],
#    'potassium': ['116 mg', '3%'],
#    'total_carbohydrate': ['0 g', '0%'],
#    'dietary_fiber': ['0 g', '0%'],
#    'sugar': ['0 g'],
#    'protein': ['0.3 g', '0%'],
#    'caffeine': ['95 mg'],
#    'vitamin_a': ['0%'],
#    'vitamin_c': ['0%'],
#    'calcium': ['0%'],
#    'iron': ['0%'],
#    'vitamin_d': ['0%'],
#    'vitamin_b_6': ['0%'],
#    'vitamin_b_12': ['0%'],
#    'magnesium': ['1%']}},
#  'related_questions': [{'question': 'What does coffee do to your body?',
#    'snippet': "Drinking large amounts of coffee can cause a spike in blood pressure and heart rate. ... There isn't a clear explanation as to why caffeine causes this increase in blood pressure, but it's likely due to increased adrenaline and other hormonal responses brought on by the stimulant.Aug 5, 2016",
#    'title': 'How Drinking Coffee Affects Your Body | SELF',
#    'link': 'https://www.self.com/story/what-drinking-coffee-actually-does-to-your-body',
#    'displayed_link': 'https://www.self.com/story/what-drinking-coffee-actually-does-to-your-body'},
#   {'question': 'What are the benefits of drinking coffee?',
#    'snippet': "The potential health benefits associated with drinking coffee include protecting against type 2 diabetes, Parkinson's disease, liver disease, liver cancer, and promoting a healthy heart.Dec 14, 2017",
#    'title': 'Coffee: Benefits, nutrition, and risks - Medical News Today',
#    'link': 'https://www.medicalnewstoday.com/articles/270202.php',
#    'displayed_link': 'https://www.medicalnewstoday.com/articles/270202.php'},
#   {'question': 'How coffee is bad for you?',
#    'snippet': 'Coffee drinkers have up to an 84% lower risk of developing cirrhosis, with the strongest effect for those who drink 4 or more cups per day (26, 27, 28). Liver cancer is also common. It is the second leading cause of cancer death worldwide. Coffee drinkers have up to a 40% lower risk of liver cancer (29, 30).',
#    'title': 'Coffee — Good or Bad? - Healthline',
#    'link': 'https://www.healthline.com/nutrition/coffee-good-or-bad',
#    'displayed_link': 'https://www.healthline.com/nutrition/coffee-good-or-bad'},
#   {'question': 'Who first drank coffee?',
#    'snippet': 'The story of Kaldi, the 9th-century Ethiopian goatherd who discovered coffee when he noticed how excited his goats became after eating the beans from a coffee plant, did not appear in writing until 1671 and is probably apocryphal.',
#    'title': 'Coffee - Wikipedia',
#    'link': 'https://en.wikipedia.org/wiki/Coffee',
#    'displayed_link': 'https://en.wikipedia.org/wiki/Coffee'}],
#  'answer_box': {'type': 'unknow'},
#  'organic_results': [{'position': 1,
#    'title': 'Coffee - Wikipedia',
#    'link': 'https://en.wikipedia.org/wiki/Coffee',
#    'displayed_link': 'https://en.wikipedia.org/wiki/Coffee',
#    'snippet': 'Coffee is a brewed drink prepared from roasted coffee beans, the seeds of berries from certain Coffea species. The genus Coffea is native to tropical Africa and\xa0...',
#    'sitelinks': {'inline': [{'title': 'History of coffee',
#       'link': 'https://en.wikipedia.org/wiki/History_of_coffee'},
#      {'title': 'Coffee bean',
#       'link': 'https://en.wikipedia.org/wiki/Coffee_bean'},
#      {'title': 'Coffee preparation',
#       'link': 'https://en.wikipedia.org/wiki/Coffee_preparation'},
#      {'title': 'Robusta coffee',
#       'link': 'https://en.wikipedia.org/wiki/Robusta_coffee'}]},
#    'cached_page_link': 'https://webcache.googleusercontent.com/search?q=cache:U6oJMnF-eeUJ:https://en.wikipedia.org/wiki/Coffee+&cd=4&hl=en&ct=clnk&gl=us',
#    'related_pages_link': 'https://www.google.com/search?gl=us&hl=en&q=related:https://en.wikipedia.org/wiki/Coffee+Coffee&tbo=1&sa=X&ved=2ahUKEwjn5s2Mr7TeAhUBOK0KHaDjAcQQHzADegQICRAF'},
#   {'position': 2,
#    'title': 'Cuvée Coffee: Always Something Brewing. Austin, TX',
#    'link': 'https://cuveecoffee.com/',
#    'displayed_link': 'https://cuveecoffee.com/',
#    'snippet': 'It began in 1998, when we started building our own direct trade network to ensure higher quality and more consistent access to our favorite coffee. More recently\xa0...',
#    'cached_page_link': 'https://webcache.googleusercontent.com/search?q=cache:9KGxqO9Ef1wJ:https://cuveecoffee.com/+&cd=5&hl=en&ct=clnk&gl=us'},
#   {'position': 3,
#    'title': "Jo's Coffee",
#    'link': 'https://www.joscoffee.com/',
#    'displayed_link': 'https://www.joscoffee.com/',
#    'snippet': "Jo's Hot Coffee Good Food. SOUTH CONGRESS AVENUE / DOWNTOWN / ST. EDWARDS CAMPUS. The Dogs of Jo's Coffee. 1.jpg 2.jpg 3.jpg 4.jpg 5.jpg 6.jpg \xa0...",
#    'cached_page_link': 'https://webcache.googleusercontent.com/search?q=cache:AUwsMkw3aIEJ:https://www.joscoffee.com/+&cd=6&hl=en&ct=clnk&gl=us'},
#   {'position': 4,
#    'title': 'Houndstooth Coffee',
#    'link': 'https://www.houndstoothcoffee.com/',
#    'displayed_link': 'https://www.houndstoothcoffee.com/',
#    'snippet': 'Houndstooth Coffee serves only the finest coffee, tea, beer, wine and pastries. Local and national suppliers source sustainable products from the finest estates, \xa0...',
#    'cached_page_link': 'https://webcache.googleusercontent.com/search?q=cache:LUlkIm1_AS4J:https://www.houndstoothcoffee.com/+&cd=7&hl=en&ct=clnk&gl=us'},
#   {'position': 5,
#    'title': 'Fleet Coffee - Austin',
#    'link': 'http://www.fleetcoffee.com/',
#    'displayed_link': 'www.fleetcoffee.com/',
#    'snippet': 'DRINKS. Coffee. Espresso. Americano. Macchiato. Cortado. Cappuccino. Latte. Drip. Iced Coffee. Kalita Pourover. Not Coffee. Strawberry Rose Soda. Iced Tea.',
#    'cached_page_link': 'http://webcache.googleusercontent.com/search?q=cache:OHMW3xP0sQMJ:www.fleetcoffee.com/+&cd=8&hl=en&ct=clnk&gl=us',
#    'related_pages_link': 'https://www.google.com/search?gl=us&hl=en&q=related:www.fleetcoffee.com/+Coffee&tbo=1&sa=X&ved=2ahUKEwjn5s2Mr7TeAhUBOK0KHaDjAcQQHzAHegQIDRAF'},
#   {'position': 6,
#    'title': 'Stouthaus Coffee - Austin',
#    'link': 'https://www.stouthauscoffee.com/',
#    'displayed_link': 'https://www.stouthauscoffee.com/',
#    'snippet': 'Community. We love people. Community. Seeing strangers become friends. Direct Trade, locally roasted coffee. Craft Beer. Yes. Coffee and Beer.',
#    'cached_page_link': 'https://webcache.googleusercontent.com/search?q=cache:F4i4m-C1FwgJ:https://www.stouthauscoffee.com/+&cd=9&hl=en&ct=clnk&gl=us',
#    'related_pages_link': 'https://www.google.com/search?gl=us&hl=en&q=related:https://www.stouthauscoffee.com/+Coffee&tbo=1&sa=X&ved=2ahUKEwjn5s2Mr7TeAhUBOK0KHaDjAcQQHzAIegQICxAF'},
#   {'position': 7,
#    'title': 'Texas Coffee Traders',
#    'link': 'https://www.texascoffeetraders.com/',
#    'displayed_link': 'https://www.texascoffeetraders.com/',
#    'snippet': 'Texas Coffee Traders is an artisanal coffee roaster and local specialist in all things coffee. Since 1994, we have provided the freshest beans and most hospitable\xa0...',
#    'cached_page_link': 'https://webcache.googleusercontent.com/search?q=cache:ZgCEMrwIOwgJ:https://www.texascoffeetraders.com/+&cd=10&hl=en&ct=clnk&gl=us'},
#   {'position': 8,
#    'title': "Mozart's Coffee - Austin",
#    'link': 'http://mozartscoffee.com/',
#    'displayed_link': 'mozartscoffee.com/',
#    'snippet': "Our Story. Mozart's is proud to be an “Austin Original”. We opened our doors in 1993 with the dream of offering a place to enjoy quality coffee in a beautiful\xa0...",
#    'cached_page_link': 'http://webcache.googleusercontent.com/search?q=cache:iyGKHKgFvPwJ:mozartscoffee.com/+&cd=11&hl=en&ct=clnk&gl=us'},
#   {'position': 9,
#    'title': 'Home | The Coffee Bean & Tea Leaf',
#    'link': 'https://www.coffeebean.com/',
#    'displayed_link': 'https://www.coffeebean.com/',
#    'snippet': 'Download The Coffee Bean® Rewards app now for exclusive goodies, plus a free brewed coffee or hot tea to welcome you into the fold. Find us in the App Store\xa0...',
#    'cached_page_link': 'https://webcache.googleusercontent.com/search?q=cache:WpQxSYo2c6AJ:https://www.coffeebean.com/+&cd=12&hl=en&ct=clnk&gl=us',
#    'related_pages_link': 'https://www.google.com/search?gl=us&hl=en&q=related:https://www.coffeebean.com/+Coffee&tbo=1&sa=X&ved=2ahUKEwjn5s2Mr7TeAhUBOK0KHaDjAcQQHzALegQIBhAF'},
#   {'position': 10,
#    'title': 'What is Coffee? - National Coffee Association',
#    'link': 'http://www.ncausa.org/about-coffee/what-is-coffee',
#    'displayed_link': 'www.ncausa.org › About Coffee › What is Coffee?',
#    'snippet': 'NCA WEBINAR | Robert Aguirre, Aguirre Coffee, will share tips and tools to help you get credible intelligence on a prospective location for your coffee business.',
#    'cached_page_link': 'http://webcache.googleusercontent.com/search?q=cache:eukMDyc_TlwJ:www.ncausa.org/about-coffee/what-is-coffee+&cd=13&hl=en&ct=clnk&gl=us'}],
#  'related_searches': [{'query': 'houndstooth coffee',
#    'link': 'https://www.google.com/search?gl=us&hl=en&q=houndstooth+coffee&sa=X&ved=0ahUKEwjn5s2Mr7TeAhUBOK0KHaDjAcQQ1QII7QEoAA'},
#   {'query': 'coffee shop',
#    'link': 'https://www.google.com/search?gl=us&hl=en&q=coffee+shop&sa=X&ved=0ahUKEwjn5s2Mr7TeAhUBOK0KHaDjAcQQ1QII7gEoAQ'},
#   {'query': 'coffee beans',
#    'link': 'https://www.google.com/search?gl=us&hl=en&q=coffee+beans&sa=X&ved=0ahUKEwjn5s2Mr7TeAhUBOK0KHaDjAcQQ1QII7wEoAg'},
#   {'query': 'coffee near me',
#    'link': 'https://www.google.com/search?gl=us&hl=en&q=coffee+near+me&sa=X&ved=0ahUKEwjn5s2Mr7TeAhUBOK0KHaDjAcQQ1QII8AEoAw'},
#   {'query': 'best coffee in austin',
#    'link': 'https://www.google.com/search?gl=us&hl=en&q=best+coffee+in+austin&sa=X&ved=0ahUKEwjn5s2Mr7TeAhUBOK0KHaDjAcQQ1QII8QEoBA'},
#   {'query': 'coffee shops austin',
#    'link': 'https://www.google.com/search?gl=us&hl=en&q=coffee+shops+austin&sa=X&ved=0ahUKEwjn5s2Mr7TeAhUBOK0KHaDjAcQQ1QII8gEoBQ'},
#   {'query': 'houndstooth coffee domain',
#    'link': 'https://www.google.com/search?gl=us&hl=en&q=houndstooth+coffee+domain&sa=X&ved=0ahUKEwjn5s2Mr7TeAhUBOK0KHaDjAcQQ1QII8wEoBg'},
#   {'query': 'coffee shops near me',
#    'link': 'https://www.google.com/search?gl=us&hl=en&q=coffee+shops+near+me&sa=X&ved=0ahUKEwjn5s2Mr7TeAhUBOK0KHaDjAcQQ1QII9AEoBw'}],
#  'pagination': {'current': 1,
#   'next': 'https://www.google.com/search?q=Coffee&gl=us&hl=en&ei=7I7bW-fAC4HwtAWgx4egDA&start=10&sa=N&ved=0ahUKEwjn5s2Mr7TeAhUBOK0KHaDjAcQQ8NMDCIsC',
#   'other_pages': {'2': 'https://www.google.com/search?q=Coffee&gl=us&hl=en&ei=7I7bW-fAC4HwtAWgx4egDA&start=10&sa=N&ved=0ahUKEwjn5s2Mr7TeAhUBOK0KHaDjAcQQ8tMDCPkB',
#    '3': 'https://www.google.com/search?q=Coffee&gl=us&hl=en&ei=7I7bW-fAC4HwtAWgx4egDA&start=20&sa=N&ved=0ahUKEwjn5s2Mr7TeAhUBOK0KHaDjAcQQ8tMDCPsB',
#    '4': 'https://www.google.com/search?q=Coffee&gl=us&hl=en&ei=7I7bW-fAC4HwtAWgx4egDA&start=30&sa=N&ved=0ahUKEwjn5s2Mr7TeAhUBOK0KHaDjAcQQ8tMDCP0B',
#    '5': 'https://www.google.com/search?q=Coffee&gl=us&hl=en&ei=7I7bW-fAC4HwtAWgx4egDA&start=40&sa=N&ved=0ahUKEwjn5s2Mr7TeAhUBOK0KHaDjAcQQ8tMDCP8B',
#    '6': 'https://www.google.com/search?q=Coffee&gl=us&hl=en&ei=7I7bW-fAC4HwtAWgx4egDA&start=50&sa=N&ved=0ahUKEwjn5s2Mr7TeAhUBOK0KHaDjAcQQ8tMDCIEC',
#    '7': 'https://www.google.com/search?q=Coffee&gl=us&hl=en&ei=7I7bW-fAC4HwtAWgx4egDA&start=60&sa=N&ved=0ahUKEwjn5s2Mr7TeAhUBOK0KHaDjAcQQ8tMDCIMC',
#    '8': 'https://www.google.com/search?q=Coffee&gl=us&hl=en&ei=7I7bW-fAC4HwtAWgx4egDA&start=70&sa=N&ved=0ahUKEwjn5s2Mr7TeAhUBOK0KHaDjAcQQ8tMDCIUC',
#    '9': 'https://www.google.com/search?q=Coffee&gl=us&hl=en&ei=7I7bW-fAC4HwtAWgx4egDA&start=80&sa=N&ved=0ahUKEwjn5s2Mr7TeAhUBOK0KHaDjAcQQ8tMDCIcC',
#    '10': 'https://www.google.com/search?q=Coffee&gl=us&hl=en&ei=7I7bW-fAC4HwtAWgx4egDA&start=90&sa=N&ved=0ahUKEwjn5s2Mr7TeAhUBOK0KHaDjAcQQ8tMDCIkC'}}}

# %%
import bs4 as bs, urllib, pandas as pd, numpy as np

# %% [markdown]
# Test parsing syntax

# %%
keyword='medve'
time1='2018-07-01'
time2='2018-08-01'
baseurl=u'https://szekelyhon.ro/kereses?op=search&src_words='
url=baseurl+keyword+'&src_time1='+time1+'&src_time2='+time2

# %%
html = urllib.request.urlopen(url).read()
soup = bs.BeautifulSoup(html,'lxml')

# %%
hirek=[]
divs=soup.findAll("div", {"class": "catinner"})
for div in divs:
    idiv=div.find('div')
    hirek.append({'date':idiv.text[idiv.text.find('201'):idiv.text.find(',')],
                  'title':div.find('h2').text,
                  'content':div.find('p').text,
                  'link':div.findAll('a')[1]['href'],
                   })

# %%
df=pd.DataFrame().from_dict(hirek)

# %%
df.loc[7]['link']
# Out:
# 'https://szekelyhon.ro/aktualis/medveterkepet-keszitettek-sepsiszentgyorgyon'

# %% [markdown]
# Parse past X years

# %%
start='2002-12-01'
end='2018-11-01'
dates=[]
datelist = pd.date_range(start=pd.to_datetime(start), end=pd.to_datetime(end), freq='M').tolist()
for date in datelist:
    dates.append(str(date)[:10])

# %%
dates[:5]
# Out:
# ['2002-12-31', '2003-01-31', '2003-02-28', '2003-03-31', '2003-04-30']

# %%
def extractor(time1,time2):
    time1=dates[i]
    time2=dates[i+1]
    print('Parsing...',time1,'-',time2)
    url=baseurl+keyword+'&src_time1='+time1+'&src_time2='+time2
    html = urllib.request.urlopen(url).read()
    soup = bs.BeautifulSoup(html,'lxml')
    return soup.findAll("div", {"class": "catinner"})

# %%
divs=[]
for i in range(len(dates)-1):
    time1=dates[i]
    time2=dates[i+1]
    divs.append(extractor(time1,time2))
# Out:
# Parsing... 2002-12-31 - 2003-01-31
# Parsing... 2003-01-31 - 2003-02-28
# Parsing... 2003-02-28 - 2003-03-31
# Parsing... 2003-03-31 - 2003-04-30
# Parsing... 2003-04-30 - 2003-05-31
# Parsing... 2003-05-31 - 2003-06-30
# Parsing... 2003-06-30 - 2003-07-31
# Parsing... 2003-07-31 - 2003-08-31
# Parsing... 2003-08-31 - 2003-09-30
# Parsing... 2003-09-30 - 2003-10-31
# Parsing... 2003-10-31 - 2003-11-30
# Parsing... 2003-11-30 - 2003-12-31
# Parsing... 2003-12-31 - 2004-01-31
# Parsing... 2004-01-31 - 2004-02-29
# Parsing... 2004-02-29 - 2004-03-31
# Parsing... 2004-03-31 - 2004-04-30
# Parsing... 2004-04-30 - 2004-05-31
# Parsing... 2004-05-31 - 2004-06-30
# Parsing... 2004-06-30 - 2004-07-31
# Parsing... 2004-07-31 - 2004-08-31
# Parsing... 2004-08-31 - 2004-09-30
# Parsing... 2004-09-30 - 2004-10-31
# Parsing... 2004-10-31 - 2004-11-30
# Parsing... 2010-05-31 - 2010-06-30
# Parsing... 2010-06-30 - 2010-07-31
# Parsing... 2010-07-31 - 2010-08-31
# Parsing... 2010-08-31 - 2010-09-30
# Parsing... 2010-09-30 - 2010-10-31
# Parsing... 2010-10-31 - 2010-11-30
# Parsing... 2010-11-30 - 2010-12-31
# Parsing... 2010-12-31 - 2011-01-31
# Parsing... 2011-01-31 - 2011-02-28
# Parsing... 2011-02-28 - 2011-03-31
# Parsing... 2011-03-31 - 2011-04-30
# Parsing... 2011-04-30 - 2011-05-31
# Parsing... 2011-05-31 - 2011-06-30
# Parsing... 2011-06-30 - 2011-07-31
# Parsing... 2011-07-31 - 2011-08-31
# Parsing... 2011-08-31 - 2011-09-30
# Parsing... 2011-09-30 - 2011-10-31
# Parsing... 2011-10-31 - 2011-11-30
# Parsing... 2011-11-30 - 2011-12-31
# Parsing... 2011-12-31 - 2012-01-31
# Parsing... 2012-01-31 - 2012-02-29
# Parsing... 2012-02-29 - 2012-03-31
# Parsing... 2012-03-31 - 2012-04-30
# Parsing... 2012-04-30 - 2012-05-31
# Parsing... 2012-05-31 - 2012-06-30
# Parsing... 2012-06-30 - 2012-07-31
# Parsing... 2012-07-31 - 2012-08-31
# Parsing... 2012-08-31 - 2012-09-30
# Parsing... 2012-09-30 - 2012-10-31
# Parsing... 2012-10-31 - 2012-11-30
# Parsing... 2012-11-30 - 2012-12-31

# %%
def date_hu_en(i):
    date=i[6:-4]
    if date=='augusztus': m='08'
    elif date=='december': m='12'
    elif date=='február': m='02'
    elif date=='január': m='01'
    elif date=='július': m='07'
    elif date=='június': m='06'
    elif date=='május': m='05'
    elif date=='március': m='03'
    elif date=='november': m='11'
    elif date==u'október': m='10'
    elif date==u'szeptember': m='09'
    elif date==u'április': m='04'
    else: return date
    return i[:4]+'-'+m+'-'+i[-3:-1]

# %% [markdown]
# Relevant = Medves cikk-e vagy sem
# Deaths = Halalok szama
# Severity = Sulyossag: 0-mas jellegu hir, 1-latas, 2-allat-tamadas, 3-ember-tamadas

# %%
def text_processor(title,content):
    relevant=0
    severity=0
    deaths=0
    tamadas=[u'támad',u'sebes']
    for i in tamadas:
        if i in title+content:
            relevant=1
            severity=2
    tamadas=[u'halál',u'áldozat',u'ölt ']
    for i in tamadas:
        if i in title+content:
            relevant=1
            severity=3
    tamadas=[u'medve',u'medvék']
    for i in tamadas:
        if i in title.replace(',',' ').replace('.',' ').lower():
            relevant=1
    return relevant,severity,deaths

# %%
hirek=[]
for divgroup in divs:
    for div in divgroup:
        idiv=div.find('div')
        content=div.find('p')
        date=idiv.text[idiv.text.find('201'):idiv.text.find(',')]
        title=div.find('h2').text
        if content==None:
            sdiv=str(div)[::-1]
            content=sdiv[:sdiv.find('>a/<')].replace('\r','').replace('\t','').replace('\n','')[::-1][:-6]
        else: content=content.text
        relevant,severity,deaths=text_processor(title,content)
        hirek.append({'date':date_hu_en(date),
                      'hudate':date,
                      'title':title,
                      'content':content,
                      'link':div.findAll('a')[-1]['href'],
                      'relevant':relevant,
                      'severity':severity,
                      'deaths':deaths
                       })

# %% [markdown]
# Összes medvés hír

# %%
len(hirek)
# Out:
# 2001

# %%
df=pd.DataFrame().from_dict(hirek)
df['date']=pd.to_datetime(df['date'])
df=df.sort_values('date').reset_index(drop=True)

# %% [markdown]
# Save to medve Excel. Manual curation

# %%
df.columns
# Out:
# Index(['content', 'date', 'deaths', 'hudate', 'link', 'relevant', 'severity',
#        'title'],
#       dtype='object')

# %%
df=df[[ 'date', 'hudate', 'link', 'title','content','relevant', 'severity','deaths']]

# %%
df.to_excel('szekelyhon_medve.xlsx')
#df.to_excel('szekelyhon_medve_curated.xlsx')

# %% [markdown]
# Manually check and curate the `curated` file. Don't touch the other one.
# Load curated

# %%
dc=pd.read_excel('szekelyhon_medve_curated.xlsx')

# %%
dg=dc[dc['relevant']==1]

# %%
dg
# Out:
#            date                hudate  \
# 68   2010-05-17       2010. május 17.
# 82   2010-06-22      2010. június 22.
# 86   2010-06-23      2010. június 23.
# 91   2010-06-30      2010. június 30.
# 97   2010-07-09      2010. július 09.
# 99   2010-07-20      2010. július 20.
# 101  2010-07-26      2010. július 26.
# 102  2010-07-26      2010. július 26.
# 103  2010-07-27      2010. július 27.
# 105  2010-07-28      2010. július 28.
# 107  2010-08-02   2010. augusztus 02.
# 122  2010-09-20  2010. szeptember 20.
# 142  2010-10-14     2010. október 14.
# 146  2010-10-20     2010. október 20.
# 151  2010-11-22    2010. november 22.
# 192  2011-01-24      2011. január 24.
# 216  2011-03-15     2011. március 15.
# 220  2011-03-29     2011. március 29.
# 235  2011-04-17     2011. április 17.
# 241  2011-05-11       2011. május 11.
# 251  2011-05-23       2011. május 23.
# 252  2011-05-23       2011. május 23.
# 265  2011-06-27      2011. június 27.
# 266  2011-06-28      2011. június 28.
# 267  2011-06-28      2011. június 28.
# 270  2011-07-19      2011. július 19.
# 274  2011-07-21      2011. július 21.
# 284  2011-08-17   2011. augusztus 17.
# 285  2011-08-18   2011. augusztus 18.
# 288  2011-08-21   2011. augusztus 21.
# ...         ...                   ...
# 1644        NaT                   NaN
# 1654        NaT                   NaN
# 1667        NaT                   NaN
# 1686        NaT                   NaN
# 1695        NaT                   NaN
# 1703        NaT                   NaN
# 1704        NaT                   NaN
# 1727        NaT                   NaN
# 1785        NaT                   NaN
# 1799        NaT                   NaN
# 1813        NaT                   NaN
# 1820        NaT                   NaN
# 1830        NaT                   NaN
# 1854        NaT                   NaN
# 1873        NaT                   NaN
# 1896        NaT                   NaN
# 1902        NaT                   NaN
# 1905        NaT                   NaN
# 1909        NaT                   NaN
# 1913        NaT                   NaN
# 1914        NaT                   NaN
# 1918        NaT                   NaN
# 1920        NaT                   NaN
# 1923        NaT                   NaN
# 1939        NaT                   NaN
# 1954        NaT                   NaN
# 1955        NaT                   NaN
# 1962        NaT                   NaN
# 1968        NaT                   NaN
# 1987        NaT                   NaN
#
#                                                    link  \
# 68    https://szekelyhon.ro/aktualis/medve-latogatta...
# 97    Jogköreik bővítését kérik a székelyföldi erdőt...
# 99                    Juhokat ölt a medve Tekerőpatakon
# 101         Gyergyószentmiklóson is juhokat ölt a medve
# 102      A kisállatok is okozhatnak károkat a gazdáknak
# 103         Újra bejártak a medvék Gyergyószentmiklósra
# 105                    Vitatható az optimális medveszám
# 107                           Románia medvét exportálna
# 122        Udvarhelyszék: medvék okozzák a legtöbb kárt
# 142                             Isten veled, Muki maci!
# 146                            medvegyev a NATO-csúcson
# 151                    EU-s pályázat: a medve nem játék
# 192               Örökbefogadással segítenek a medvéken
# 216                   Megkezdődött az éves vadszámlálás
# 220             A hegyekben van a védett vadak többsége
# 235                    Vadszámlálás: sok a fiatal medve
# 241   Áttelepítették a Tusnádfürdőn garázdálkodó med...
# 251                                medvetámadás Baróton
# 252                     Újabb medvetámadás Háromszéken
# 265   medve-látogatás az erdélyi magyar iskolák spor...
# 266                            medvetámadás Erdővidéken
# 267                     medve garázdálkodik Erdővidéken
# 270                  Garázdálkodó vaddisznók a határban
# 274   Tusványos: sátorbontó szélvihar és brummogó lá...
# 284                          medvelesre invitál az EMIA
# 285                            Autonóm székely turizmus
# 288   Paradigmaváltás és az irodalom – medvelesen vo...
# ...                                                 ...
# 1644                          „Háziasult” medveállomány
# 1654                            medve támadt a kisfiúra
# 1667                    medvevadítás: távol az embertől
# 1686                            Négyszemközt a medvével
# 1695                    medvéktől rettegnek Háromszéken
# 1703                 Lelőtték a támadó zernyesti medvét
# 1704                                            Röviden
# 1727                        Vadorzás miatt vizsgálódnak
# 1785                           medveveszély Háromszéken
# 1799                      Csökkentenék a medveállományt
# 1813                                            Röviden
# 1820                              Elijesztik a medvéket
# 1830                             medveveszély Bereckben
# 1854           medve ölte meg a csendőrt Székelyföldön
# 1873                 Feltérképezik a kovásznai medvéket
# 1896   medvék riogatják a turistákat a Szent Anna-tónál
# 1902                   „Eltitkolt” háromszéki barlangok
# 1905        medve tépett szét egy férfit Maros megyében
# 1909  medve támadt magyarországi turistákra a Bucsec...
# 1913   medvék riogatják a turistákat a Szent Anna-tónál
# 1914        medve támadt juhászra a Gyergyói-medencében
# 1918                         medvetámadás  a Bucsecsben
# 1920  Újabb medvetámadás a Bucsecs-hegységben, két f...
# 1923        medve tépett szét egy férfit Maros megyében
# 1939                Újabb medvetámadás Hargita megyében
# 1954                   medvetámadásokról szól az Átjáró
# 1955                    Farkasok, medvék és egyéb vadak
# 1962               Zernyestre költöztek a váradi medvék
# 1968               Újabb medvelátogatás Kápolnásfaluban
# 1987                                 Székely medveriadó
#
#                                                 content  relevant  severity  \
# 68    Szombatról vasárnapra virradó éjszaka a 112-es...         1         1
# 82    Ismét lakóterületre merészkednek a medvék – a ...         1         1
# 86    Valósággal rettegésben tartja a Kovászna megye...         1         1
# 91    Idén sem maradt el a hagyományosan a Szent Ann...         1         1
# 97    Több mint 150 Hargita és Kovászna megyei közbi...         1         0
# 99    medve pusztított hétfőről keddre virradóra töb...         1         2
# 1923  medve támadt egy férfira a Marosvécs községhez...         1         3
# 1939  Ismét medve támadott egy emberre Hargita megyé...         1         3
# 1954  A székelyföldi medvetámadásokról szól a Magyar...         1         0
# 1955  Farkas sétál Marosvásárhely utcáin. S ez nem v...         1         0
# 1962  A Brassó megyei Zernyest medverezervátumába kö...         1         0
# 1968  Kápolnásról kaptuk a hírt, hogy a múlt héten m...         1         1
# 1987  Élelmet kereső medvék garázdálkodnak a székely...         1         0
#
#       deaths  duplicate
# 68         0          0
# 82         0          0
# 86         0          0
# 91         0          0
# 97         0          0
# 99         0          0
# 101        0          0
# 102        0          0
# 103        0          0
# 105        0          0
# 107        0          0
# 122        0          0
# 142        0          0
# 146        0          0
# 151        0          0
# 192        0          0
# 216        0          0
# 220        0          0
# 235        0          0
# 241        0          0
# 251        0          0
# 252        0          0
# 265        0          0
# 266        0          0
# 267        0          0
# 270        0          0
# 274        0          0
# 284        0          0
# 285        0          0
# 288        0          0
# ...      ...        ...
# 1644       0          0
# 1654       0          0
# 1667       0          0
# 1686       0          0
# 1695       0          0
# 1703       1          0
# 1704       1          1
# 1727       0          0
# 1785       0          0
# 1799       0          0
# 1813       0          0
# 1820       0          0
# 1830       0          0
# 1854       1          0
# 1873       0          0
# 1896       0          0
# 1902       0          0
# 1905       1          0
# 1909       0          0
# 1913       0          0
# 1914       0          0
# 1918       0          0
# 1920       0          1
# 1923       0          0
# 1939       0          0
# 1954       0          0
# 1955       0          0
# 1962       0          0
# 1968       0          0
# 1987       0          0
#
# [444 rows x 9 columns]

# %% [markdown]
# Further fixes from full text

# %%
hirek_full=[]
for divgroup in divs:
    for div in divgroup:
        hirek_full.append(div)

# %%
df=pd.DataFrame().from_dict(hirek)
df['date']=pd.to_datetime(df['date'])
df=df.sort_values('date').reset_index()

# %%
index_converter=list(df['index'])

# %%
hirek[index_converter[252]]
# Out:
# {'date': '2011-05-23',
#  'hudate': '2011. május 23.',
#  'title': ' Újabb medvetámadás Háromszéken ',
#  'content': 'Medve támadt egy erdővidéki férfire, az anyamedve a Barót melletti erdőkben rontott rá az 50 éves férfira, és összemarcangolta a felsőtestét. ',
#  'link': 'https://szekelyhon.ro/',
#  'relevant': 1,
#  'severity': 2,
#  'deaths': 0}

# %%
hirek[index_converter[1987]]
# Out:
# {'date': '',
#  'hudate': '',
#  'title': 'Székely medveriadó',
#  'content': 'Élelmet kereső medvék garázdálkodnak a székelyföldi településeken az ott élők és a környékre látogató turisták rémületére. A jelenség aggodalomra ad okot, mivel eddig errefelé nem volt példa rá, hogy a medvék nappal is lemerészkedjenek a településekre. A vadállatok egyelőre nem veszélyeztették az emberek testi épségét, Gyergyószéken azonban napi rendszerességgel tizedelik a háziállat-állományt. A „medvelátogatásokról” egyébként meglehetősen...',
#  'link': 'https://szekelyhon.ro/',
#  'relevant': 1,
#  'severity': 0,
#  'deaths': 0}

# %%
medve site:szekelyhon.ro

# %%
medve site:transindex.ro

# %%
medve site:maszol.ro

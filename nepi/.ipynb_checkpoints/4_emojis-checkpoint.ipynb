# %%
import pandas as pd, numpy as np
from scipy import stats

# %%
df=pd.read_html('https://en.wikipedia.org/wiki/List_of_emojis')

# %%
all_emojis=''.join(df[0].stack().unique())

# %%
k=45
all_emojis2='\n'.join([all_emojis[i:i+k] for i in range(0, len(all_emojis), k)])
fig,ax=plt.subplots(1,1,figsize=(14,6))
plt.text(0,0,all_emojis2[100:700],fontproperties=prop2,fontsize=30,);

# %%
all_emojis2[200:700]
# Out:
# 'U+25Cx◀️U+25Fx◻️◼️◽️◾️U+260x☀\n️☁️☂️☃️☄️☎️U+261x☑️☔️☕️☘️☝️U+262x☠️☢️☣️☦️☪️☮️\n☯️U+263x☸️☹️☺️U+264x♀️♂️♈️♉️♊️♋️♌️♍️♎️♏️U+265\nx♐️♑️♒️♓️U+266x♠️♣️♥️♦️♨️U+267x♻️♿️U+269x⚒️⚓️\n⚔️⚕️⚖️⚗️⚙️⚛️⚜️U+26Ax⚠️⚡️⚪️⚫️U+26Bx⚰️⚱️⚽️⚾️U+2\n6Cx⛄️⛅️⛈️⛎️⛏️U+26Dx⛑️⛓️⛔️U+26Ex⛩️⛪️U+26Fx⛰️⛱️\n⛲️⛳️⛴️⛵️⛷️⛸️⛹️⛺️⛽️U+270x✂️✅️✈️✉️✊️✋️✌️✍️✏️U+2\n71x✒️✔️✖️✝️U+272x✡️✨️U+273x✳️✴️U+274x❄️❇️❌️❎️\nU+275x❓️❔️❕️❗️U+276x❣️❤️U+279x➕️➖️➗️U+27Ax➡️U\n+27Bx➰️➿️U+293x⤴️⤵️U+2B0x⬅️⬆️⬇️U+2B1x⬛️⬜️U+2B\n5x⭐️⭕️U+303x〰️〽️U+329x㊗️㊙️U+1F00x🀄U+1F0Cx🃏U+1\nF17x🅰️🅱️🅾️'

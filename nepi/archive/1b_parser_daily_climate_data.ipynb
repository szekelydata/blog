# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ro=['CDO2158048062596']
hu=['CDO922768062494']

# %%
p='C:/Users/csala/Onedrive - Lancaster University/Datarepo/szekelydata/klima/daily/'

# %%
dfs=[]
for i in ro:
    df=pd.read_csv(p+'raw/ro/'+i+'.txt')
    dfs.append(df)
    print(i)
# Out:
# CDO2158048062596

# %%
dfs=pd.concat(dfs)

# %%
dfs['time']=pd.to_datetime(df[' YEARMODA'],format='%Y%m%d')

# %%
dfs
# Out:
#        STN---  WBAN    YEARMODA     TEMP         DEWP    .1    SLP      .2  \
# 0      154200  99999   19520102     38.8   4     38.3     4   1015.0     4
# 1      154200  99999   19520103     38.3   4     37.3     4   1019.8     4
# 2      154200  99999   19520104     36.3   4     34.0     4   1015.2     4
# 3      154200  99999   19520106     34.2   4     24.3     4   1021.8     4
# 4      154200  99999   19520107     32.8   4     20.8     4   1030.0     4
# ...       ...    ...        ...      ...  ..      ...   ...      ...   ...
# 21864  154200  99999   20191028     50.3  24     46.4    24   9999.9     0
# 21865  154200  99999   20191029     51.5  24     48.3    24   9999.9     0
# 21866  154200  99999   20191030     47.6  24     42.9    24   9999.9     0
# 21867  154200  99999   20191031     41.9  24     37.7    24   9999.9     0
# 21868  154200  99999   20191101     41.2  24     31.0    24   9999.9     0
#
# ...

# %%
for stn in dfs['STN---'].unique():
    d=dfs[dfs['STN---']==stn]
    d.to_csv(p+'export/'+str(stn)+'.csv')
    print(stn)
# Out:
# 154200

# %%
import facebook

#szd graph = facebook.GraphAPI(access_token="EAAMCFinkT6QBALoV1w0bDcFhLemBJRuIGMMwGRqNSuSqKq8i3XuCGZAtfbJknSkZB7qtjZCrgq08MsBm19A5y5poZBJaEchlqpbh8IFdv3wR34gZBSSi6L58BhYyy4brq9mNKXuaSwBz4jghnnDm6oT49b45F4AK6WdUZBQWu2KrZCl8Aywe9dwqC30ltuwscsZD")
tkn='EAACEdEose0cBAMhZCV5cSBwDIuAwke8V38Vn0a7KbtQWl22gR5burYUbMrkgmZC4GIvsTVZBneMElsDaunBZCoHWe9U0lCps0qTycwDEd3oW4hRnOdspEZCakFPLV6u5Jvuk7d0Fu1B94JFL0DeyK2aNwO3EIuW5y9Ae148NR04kyUbRyoDRysCYxZAz2ScekZD'
graph = facebook.GraphAPI(access_token=tkn,version="2.7")

# %%
friends = graph.get_connections(id='me', connection_name='friends')

# %%
friends
# Out:
# {u'data': [{u'id': u'10153344164147585', u'name': u'Hicham A Houmane'},
#   {u'id': u'10152287413049627', u'name': u'Vanson Tzu-Chun Lin'},
#   {u'id': u'10153491338166815', u'name': u'Adel Seif El Nasr'},
#   {u'id': u'558010275', u'name': u'Prajowal Manandhar'},
#   {u'id': u'10152447027039836', u'name': u'Kasun Sanjeewa Perera'},
#   {u'id': u'765539625', u'name': u'Orban Botond'},
#   {u'id': u'10152771279808836', u'name': u'Ahmad Fajar Firdaus'},
#   {u'id': u'10203545703378603', u'name': u'Rafael Harutyunyan'},
#   {u'id': u'1254725369', u'name': u'Adam Juras'},
#   {u'id': u'10202457404516543', u'name': u'Ily\xe9s Vir\xe1g'},
#   {u'id': u'911828858844802', u'name': u'Ivett Kov\xe1cs'},
#   {u'id': u'1119229718105508', u'name': u'S\xe1ndor Csan\xe1d'},
#   {u'id': u'1146225202074420', u'name': u'Bijay Neupane'},
#   {u'id': u'1076366182393968', u'name': u'Telegdy Bal\xe1zs'},
#   {u'id': u'701998419841654', u'name': u'Hunor Kov\xe1csLove'},
# ...

# %%
import facebook
aToken = "your access tocken"

graph = facebook.GraphAPI(access_token=aToken, version="2.1")
data = graph.search(
            q='aquafresh',
            type='post'
            )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-72ed1887bec9> in <module>()
#       3
#       4 graph = facebook.GraphAPI(access_token=aToken, version="2.1")
# ----> 5 data = graph.search(
#       6             q='aquafresh',
#       7             type='post'
#
# AttributeError: 'GraphAPI' object has no attribute 'search'

# %%
import requests
token = "your_token"
query = "szekelydata"
r=requests.get("https://graph.facebook.com/search?access_token=" + tkn +  "&q=" + query + "&type=page")

# %%
r.content
# Out:
# '{"data":[{"name":"Sz\\u00e9kelydata","id":"1312599405461876"}],"paging":{"cursors":{"before":"MAZDZD","after":"MAZDZD"}}}'

# %%
help(facebook)
# Out:
# Help on package facebook:
#
# NAME
#     facebook - Python client library for the Facebook Platform.
#
# FILE
#     c:\users\csala\appdata\local\continuum\anaconda2\lib\site-packages\facebook\__init__.py
#
# DESCRIPTION
#     This client library is designed to support the Graph API and the
#     official Facebook JavaScript SDK, which is the canonical way to
#     implement Facebook authentication. Read more about the Graph API at
#     https://developers.facebook.com/docs/graph-api.
#
# PACKAGE CONTENTS
#     version
#
# CLASSES
#     __builtin__.object
#         GraphAPI
#     exceptions.Exception(exceptions.BaseException)
#         GraphAPIError
#
#     class GraphAPI(__builtin__.object)
#      |  A client for the Facebook Graph API.
#      |
#      |  https://developers.facebook.com/docs/graph-api
#      |
#      |  The Graph API is made up of the objects in Facebook (e.g., people,
#      |  pages, events, photos) and the connections between them (e.g.,
# ...

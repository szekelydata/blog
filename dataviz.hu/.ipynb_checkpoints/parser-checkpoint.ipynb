# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('2013_2017_monthly_BUD_traffic.csv',encoding='latin-1',sep=';')

# %%
df['LF']=df[' PAX']/df['Capacity']

# %%
df.plot(kind='scatter',x='ATM',y='LF')

# %%
import plotly.plotly as py
import plotly.tools as tls
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
dz=df.groupby(['Year','City']).sum()
dz['LF']=dz[' PAX']/dz['Capacity']

# %%
fig = {
    'data': [
  		{
  			'x': dz.loc[2013]['ATM'], 
        	'y': dz.loc[2013]['LF'], 
        	'text': dz.loc[2013].index, 
        	'mode': 'markers', 
        	'name': '2013'},
        {
  			'x': dz.loc[2017]['ATM'], 
        	'y': dz.loc[2017]['LF'], 
        	'text': dz.loc[2017].index, 
        	'mode': 'markers', 
        	'name': '2017'},
        {
  			'x': dz.loc[2015]['ATM'], 
        	'y': dz.loc[2015]['LF'], 
        	'text': dz.loc[2015].index, 
        	'mode': 'markers', 
        	'name': '2015'}
    ],
    'layout': {
        'xaxis': {'title': 'ATM','type':'log'},
        'yaxis': {'title': "LF"}
    }
}

# %%
iplot(fig, filename='plot1')
# Out:
# <div id="dd5e32dd-7fa6-4919-950f-e5034c90faf4" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("dd5e32dd-7fa6-4919-950f-e5034c90faf4", [{"mode": "markers", "name": "2013", "text": ["Alicante", "Amsterdam", "Angers", "Ankara", "Antalya", "Aqaba", "Argost\u00f3lion", "Assiut", "Athens", "Atyrau", "Baku", "Barcelona", "Bari", "Basel", "Beirut", "Belgrade", "Berlin", "Bern", "Bilbao", "Billund", "Birmingham", "Bodrum", "Bologna", "Bordeaux", "Bourgas", "Bratislava", "Brescia", "Bristol", "Brussels", "Bucharest", "Cairo", "Casablanca", "Catania", "Clermont ", "Cluj", "Cold Bay", "Cologne", "Copenhagen", "Corfu", "Debrecen", "Delhi", "Dijon", "Djerba", "Doha", "Dortmund", "Dresden", "Dubai", "Dublin", "Dubrovnik", "Dusseldorf", "ENFIDHA", "East Midlands", "Edinburgh", "Egilsstadir", "Eindhoven", "Ekaterinburg", "Eskisehir", "Frankfurt", "Friedrichshafen", "Gdansk", "Geneva", "Glasgow", "Gothenburg", "Hahn", "Hamburg", "Harstad Narvik", "Helsinki", "Heraklion", "Hurghada", "INVERNESS", "Innsbruck", "Islamabad", "Istanbul", "Izmir", "Karlsruhe", "Katowice", "Kiev", "Kos", "Kosice", "Krakow", "Lamezia", "Larnaca", "Lemwerder", "Lisbon", "London", "Lvov", "Lyon", "Madrid", "Malaga", "Malmo", "Malta", "Manchester", "Marseille", "Memmingen", "Milan", "Minsk", "Monastir", "Moscow", "Mulhouse", "Munich", "Muscat", "Nantes", "Naples", "Norrkoping", "Oslo", "Paderborn", "Palermo", "Palma De Mallorca", "Paphos", "Paris", "Pisa", "Podgorica", "Poznan", "Prague", "Pristina", "Reykjavik", "Rhodos", "Riga", "Rome", "Rostov", "Rotterdam", "Rovaniemi", "Sandefjord", "Santiago de Compostela", "Sharm el Sheikh", "Skopje", "Sliac", "Sochi", "Sofia", "St.Petersburg", "Stockholm", "Strasbourg", "Stuttgart", "TROMSO", "Tallin", "Tampere", "Tel Aviv", "Tenerife", "Thessaloniki", "Tirgu Mures", "Tokio", "Torino", "Toulouse", "Treviso", "Trondheim", "Tunis", "Turku", "Valencia", "Valladolid", "Varna", "Venezia", "Vienna", "Warsaw", "Zadar", "Zagreb", "Zakinthos", "Zaporozhye", "Zilina", "Zurich"], "x": [138, 2579, 1, 1, 424, 55, 30, 1, 260, 24, 114, 789, 223, 414, 2, 62, 1969, 130, 14, 310, 6, 31, 8, 1, 158, 2, 1, 221, 3699, 1390, 517, 2, 152, 1, 6, 1, 692, 813, 113, 2, 2, 1, 40, 730, 610, 2, 74, 1034, 3, 1212, 83, 32, 274, 6, 1394, 7, 1, 3259, 1, 2, 1126, 2, 576, 258, 686, 2, 1547, 131, 226, 2, 3, 1, 1689, 2, 8, 2, 671, 11, 1, 10, 1, 274, 1, 743, 7227, 2, 236, 771, 80, 490, 231, 730, 9, 1, 1873, 62, 169, 1654, 1, 3324, 1, 15, 273, 2, 983, 1, 20, 111, 130, 3128, 164, 4, 3, 1705, 6, 17, 93, 408, 2170, 7, 262, 2, 2, 1, 71, 2, 5, 2, 91, 125, 1349, 11, 1159, 2, 1, 210, 1460, 62, 127, 248, 2, 2, 4, 260, 1, 8, 52, 17, 6, 54, 1, 2095, 2601, 1, 725, 87, 1, 1, 2185], "y": [0.9033049612759758, 0.8372919936095913, 0.3010752688172043, 0.5181818181818182, 0.9055184960582171, 0.7611408199643493, 0.9703703703703703, 0.006944444444444444, 0.78162157101395, 0.5176686553464892, 0.6029239766081871, 0.8940656176077343, 0.7956191617962936, 0.8955468846773195, 0.9, 0.46612119662490414, 0.7388378992660964, 0.5389384920634921, 0.8846009741476208, 0.7400921658986175, 0.7689594356261023, 0.880300590445518, 0.7439716312056738, 1.0, 0.8402134333201139, 0.4732620320855615, 0.005747126436781609, 0.8894874188991836, 0.7524946904449353, 0.6703848966296616, 0.7039278103706822, 0.32266666666666666, 0.858525413711584, 0.9312169312169312, 0.5521739130434783, 0.7571428571428571, 0.7338358719303699, 0.7250371231703581, 0.9160657051282052, 0.8722222222222222, 0.5185185185185185, 0.9785714285714285, 0.8870673952641166, 0.8863291337350341, 0.8351644347271567, 0.175, 0.6398648648648648, 0.8675533241695547, 0.7610062893081762, 0.6563499250120264, 0.89251632345555, 0.8249577702702703, 0.9307269213616768, 0.6971326164874552, 0.820995765805227, 0.6995073891625616, 0.9559748427672956, 0.7641386818557445, 0.5285714285714 ...

# %%
import numpy as np

# %%
fig = {
    'data': [
  		{
  			'x': dz.loc[2013]['ATM']/365*(1+np.random.randn(len(dz.loc[2013]))), 
        	'y': dz.loc[2013]['LF'], 
        	'text': dz.loc[2013].index, 
        	'mode': 'markers', 
        	'name': '2013'},
        {
  			'x': dz.loc[2017]['ATM']/365*(1+np.random.randn(len(dz.loc[2017]))),
        	'y': dz.loc[2017]['LF'], 
        	'text': dz.loc[2017].index, 
        	'mode': 'markers', 
        	'name': '2017'},
        {
  			'x': dz.loc[2015]['ATM']/365*(1+np.random.randn(len(dz.loc[2015]))),
        	'y': dz.loc[2015]['LF'], 
        	'text': dz.loc[2015].index, 
        	'mode': 'markers', 
        	'name': '2015'}
    ],
    'layout': {
        'xaxis': {'title': 'ATM','type':'log'},
        'yaxis': {'title': "LF"}
    }
}
iplot(fig, filename='plot1')
# Out:
# <div id="1941aa81-8fd8-45c5-bcd9-e4d6be3b17f7" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("1941aa81-8fd8-45c5-bcd9-e4d6be3b17f7", [{"mode": "markers", "name": "2013", "text": ["Alicante", "Amsterdam", "Angers", "Ankara", "Antalya", "Aqaba", "Argost\u00f3lion", "Assiut", "Athens", "Atyrau", "Baku", "Barcelona", "Bari", "Basel", "Beirut", "Belgrade", "Berlin", "Bern", "Bilbao", "Billund", "Birmingham", "Bodrum", "Bologna", "Bordeaux", "Bourgas", "Bratislava", "Brescia", "Bristol", "Brussels", "Buc